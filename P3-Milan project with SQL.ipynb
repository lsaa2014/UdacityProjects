# %% [markdown]
# ## Wrangling Milan OpenStreetMap with SQL project
#
# In this project I will use the data wrangling techniques to:
# - Audit map data of the city of Milan (Italy)
# - Fix problems encountered and enhance data quality
# - Import data into an sqlite database to perform some exploratory queries
#
# Where I found the data Map?
#
# I downloaded Milan Map from [Mapzen - Metro Extracts](https://mapzen.com/data/metro-extracts/)
# I have chosen [Milan](https://en.wikipedia.org/wiki/Milan) because I have been there several times. Milan is the economic city of Italy because is the main city for business, and Rome is for tourism.
# The overall filesize of the unzipped xml file is ~703mb.
# After downloading the xml file the data wrangling process I started looking at:
# - Element adress street
# - Element building
# - Element brand
# I found some validity, accuracy and consistency problems in these elements. For example:
# tag k="building" v="garage" />
# tag k="building" v="garages" />
# tag k="building" v="garges" />
# tag k="brand" v="Total Erg" />
# tag k="brand" v="TotalErg" />
# tag k="addr:street" v="SP 121 Pobbiano - Agrate" />
# tag k="addr:street" v="SP 121 Pobbiano - Agrate" />
# tag k="addr:street" v="Strada Provinciale 121" />
#
# The streets in Italy are person's name so a number is not valid, I found two numbers and I changed into the name.
# The building have some errors like "garges" should be "garage".
# I only used the sample file on these code as my computer run out the memory using the all data.

# %%
### I firsly take a sample from the original using this code
"""
import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

OSM_FILE = "milan_italy.osm"  
SAMPLE_FILE = "Milano.osm"

k = 10 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
      Yield element if it is the right type of tag


    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
"""

# %%
### Import all the libraries that I will use
import os
import xml.etree.ElementTree as ET
from collections import defaultdict
import re
import pprint
import csv
import codecs
import cerberus

# %%
os.getcwd()
path = 'C:\Users\SAMSUNG\Documents\Udacity\Nano_degree_Data_analyst\P3 - Wrangle OpenStreetMap Data'
print 'The size in bytes of the data sample is = {} bytes'.format(os.path.getsize('Milano.osm'))
print 'The size in bytes of the original data is = {} bytes'.format(os.path.getsize('Milan_italy.osm'))
print 'The size in bytes of the original data unzziped is = {} bytes'.format(os.path.getsize('milan_italy.osm.bz2'))
# Out:
# The size in bytes of the data sample is = 74581623 bytes
# The size in bytes of the original data is = 737747411 bytes
# The size in bytes of the original data unziped is = 56250793 bytes

# %%
###ITERATIVE PARSING ON THE SAMPLE FILE
"""
I used the iterative parsing to to process the map file and find out not only what tags and k attributes are there, but also how many, to get the
also how much of which data you can expect to have in the map.
"""

def count_tags(filename):
    
    with open(filename, 'rt') as f:
        tree = ET.parse(filename)
        
        count = dict()
        for child in tree.iter():
            if child.tag in count:
                count[child.tag] = count[child.tag] + 1
            else:   
                count[child.tag] = 1
    return count

def count_keys(filename):
            
    keys = dict()
    for event, elem in ET.iterparse(filename, events = ('start',)):
        if elem.tag == 'way':
            for tag in elem.iter('tag'):
                k = tag.attrib['k']
                if k in keys: 
                    keys[k] = keys[k] + 1
                else:
                    keys[k] = 1
                        
    return keys

def test():

    tags = count_tags('Milano.osm')
    keys = count_keys('Milano.osm')
    print 'Tags type and number'
    pprint.pprint(tags)
    print 'keys type and number'
    pprint.pprint(keys)
    

if __name__ == "__main__":
    test()
# Out:
# Tags type and number
# {'member': 10568,
#  'nd': 402843,
#  'node': 330438,
#  'osm': 1,
#  'relation': 1266,
#  'tag': 169660,
#  'way': 49979}
# keys type and number
# {'abandoned': 5,
#  'abandoned:building': 1,
#  'abandoned:highway': 1,
#  'abutters': 1,
#  'access': 1408,
#  'access:backward': 2,
#  'access:conditional': 8,
#  'access:forward': 4,
#  'access:lanes': 1,
#  'addr:city': 652,
#  'addr:country': 320,
#  'addr:housename': 35,
#  'addr:housenumber': 479,
#  'addr:inclusion': 1,
#  'addr:interpolation': 30,
#  'addr:place': 9,
#  'addr:postcode': 619,
#  'addr:province': 129,
#  'addr:street': 711,
#  'admin_level': 80,
#  'aerialway': 1,
#  'aeroway': 21,
#  'agricultural': 12,
#  'alt_name': 260,
#  'alt_name:2': 13,
#  'alt_ref': 23,
#  'amenity': 1636,
#  'animal': 1,
#  'area': 217,
#  'artist_name': 1,
#  'artwork_type': 1,
#  'asphalt': 1,
#  'atm': 3,
#  'author': 1,
#  'automated': 1,
#  'backrest': 11,
#  'barrier': 1662,
#  'basin': 2,
#  'bench': 5,
#  'bicycle': 882,
#  'bicycle:backward': 4,
#  'bicycle:forward': 3,
#  'bicycle_parking': 2,
#  'bicycle_road': 7,
#  'boat': 16,
#  'border_type': 10,
#  'boules': 1,
#  'boundary': 124,
#  'brand': 17,
#  'bridge': 417,
#  'bridge:movable': 1,
#  'bridge:name': 1,
#  'bridge:structure': 3,
#  'building': 21462,
#  'building:colour': 5,
#  'building:levels': 1271,
#  'building:levels:underground': 2,
#  'building:material': 6,
#  'building:min_level': 3,
#  'building:min_levels': 1,
#  'building:part': 81,
#  'building:roof': 1,
#  'building:use': 5,
#  'bus': 22,
#  'bus:backward': 3,
#  'bus:forward': 2,
#  'busway': 2,
#  'busway:right': 3,
#  'cables': 32,
#  'camper': 1,
#  'capacity': 52,
#  'capacity:disabled': 60,
#  'capacity:parent': 13,
#  'capacity:women': 13,
#  'city:left': 21,
#  'city:right': 21,
#  'club': 1,
#  'colonnade:right': 1,
#  'colour': 1,
#  'comment': 110,
#  'comment:2': 4,
#  'comment:2:en': 1,
#  'comment:2:it': 1,
#  'comment:en': 4,
#  'comment:it': 16,
#  'construction': 30,
#  'contact:email': 7,
#  'contact:facebook': 2,
#  'contact:fax': 6,
#  'contact:google_plus': 1,
#  'contact:mail': 2,
#  'contact:mobile': 2,
#  'contact:phone': 13,
#  'contact:tripadvisor': 1,
#  'contact:twitter': 1,
#  'contact:website': 4,
#  'conveying': 30,
#  'covered': 101,
#  'craft': 4,
#  'created_by': 62,
#  'crop': 12,
#  'crossing': 60,
#  'cuisine': 14,
#  'cutline': 1,
#  'cutting': 89,
#  'cycleway': 100,
#  'cycleway:left': 5,
#  'cycleway:right': 19,
#  'cycling_width': 1234,
#  'cycling_width:backward': 3,
#  'cycling_width:forward': 3,
#  'delivery': 1,
#  'denomination': 84,
#  'description': 31,
#  'description:en': 2,
#  'description:it': 1,
#  'designation': 2,
#  'destination': 16,
#  'destination:lanes': 1,
#  'diaper': 1,
#  'diet:gluten_free': 1,
#  'diet:vegetarian': 1,
#  'dispensing': 2,
#  'disused': 2,
#  'disused:amenity': 2,
#  'disused:building': 1,
#  'disused:highway': 2,
#  'disused:man_made': 1,
#  'disused:public_transport': 1,
#  'disused:railway': 1,
#  'disused:shop': 4,
#  'dog': 2,
#  'drinking_water': 2,
#  'driveway': 3,
#  'ele': 5,
#  'ele:local': 1,
#  'electrified': 680,
#  'email': 31,
#  'embankment': 188,
#  'emergency': 24,
#  'enforcement': 1,
#  'est_width': 34,
#  'fast_food': 1,
#  'fax': 14,
#  'fee': 145,
#  'fee:conditional': 2,
#  'fence:type': 2,
#  'fence_type': 56,
#  'fenced': 1,
#  'fishing': 1,
#  'fixme': 218,
#  'fixme:loc_ref': 1,
#  'fixme:vehicle': 1,
#  'foot': 849,
#  'foot:backward': 3,
#  'foot:conditional': 2,
#  'footway': 205,
#  'ford': 2,
#  'frequency': 600,
#  'fuel:GTL_diesel': 2,
#  'fuel:HGV_diesel': 1,
#  'fuel:cng': 1,
#  'fuel:diesel': 5,
#  'fuel:lpg': 2,
#  'fuel:octane_95': 5,
#  'furniture': 1,
#  'garden:type': 3,
#  'gauge': 716,
#  'generator:method': 5,
#  'generator:output:electricity': 5,
#  'generator:source': 6,
#  'generator:type': 2,
#  'genus': 2,
#  'golf': 61,
#  'golf_cart': 3,
#  'goods': 8,
#  'goods:conditional': 1,
#  'handrail': 40,
#  'handrail:center': 1,
#  'handrail:left': 3,
#  'handrail:right': 3,
#  'hazmat': 8,
#  'height': 2314,
#  'heritage': 1,
#  'heritage:operator': 1,
#  'hgv': 67,
#  'hgv:conditional': 2,
#  'highspeed': 15,
#  'highway': 17186,
#  'historic': 25,
#  'historic:civilization': 1,
#  'historic:period': 1,
#  'historic_ref': 3,
#  'history': 8,
#  'hoops': 4,
#  'horse': 147,
#  'hour_off': 2,
#  'hour_on': 2,
#  'hov': 6,
#  'hvg': 1,
#  'image': 2,
#  'importance': 2,
#  'incline': 221,
#  'indoor': 7,
#  'industrial': 1,
#  'information': 1,
#  'int_name': 1,
#  'int_ref': 35,
#  'intermittent': 7,
#  'internet_access': 6,
#  'internet_access:fee': 6,
#  'is_in': 36,
#  'is_in:city': 15,
#  'is_in:town': 10,
#  'is_in:village': 2,
#  'isced:level': 24,
#  'it:lo:CLAS': 204,
#  'it:lo:CODI': 1,
#  'it:lo:FEAT': 204,
#  'it:lo:ID_E': 204,
#  'it:lo:ID_Z': 204,
#  'it:lo:STRA': 203,
#  'it:lo:TEMA': 203,
#  'it:lo:UN_V': 202,
#  'it:lo:cl_agr_ty': 1,
#  'it:lo:sp_acq_ty': 2,
#  'it:lomb:ctrn:canale:eid': 4,
#  'it:lombardia:ctrn:cascina:CS_ID': 38,
#  'it:lombardia:ctrn:localita_significativa:COD_ISTAT': 1,
#  'it:lombardia:ctrn:localita_significativa:DTIPO_CTR': 1,
#  'it:lombardia:ctrn:localita_significativa:FID': 1,
#  'it:lombardia:ctrn:localita_significativa:TIPO_CTR': 1,
#  'it:lombardia:ctrn:strade_principali:COD_PE': 14,
#  'it:lombardia:ctrn:strade_principali:DTIPOPE': 15,
#  'it:lombardia:ctrn:strade_principali:NOME_PE0': 15,
#  'it:lombardia:ctrn:strade_secondarie:DTIPOARCO': 39,
#  'it:lombardia:ctrn:strade_secondarie:FID_': 39,
#  'it:lombardia:ctrn:strade_secondarie:OBJECTID': 39,
#  'junction': 591,
#  'landcover': 1,
#  'landuse': 2317,
#  'lanes': 1732,
#  'lanes:backward': 6,
#  'lanes:forward': 8,
#  'lanes:psv': 5,
#  'lanes:psv:backward': 3,
#  'lanes:psv:forward': 1,
#  'lay': 1,
#  'layer': 1511,
#  'leaf_cycle': 11,
#  'leaf_type': 8,
#  'leisure': 943,
#  'length': 1,
#  'level': 44,
#  'line': 30,
#  'lit': 2489,
#  'loc_name': 66,
#  'loc_ref': 3711,
#  'loc_ref:verified': 1,
#  'location': 1,
#  'lock': 1,
#  'man_made': 138,
#  'material': 19,
#  'maxaxleload': 3,
#  'maxheight': 33,
#  'maxlength': 2,
#  'maxlength:conditional': 1,
#  'maxspeed': 1502,
#  'maxspeed:backward': 1,
#  'maxspeed:bicycle': 29,
#  'maxspeed:forward': 1,
#  'maxstay': 5,
#  'maxstay:conditional': 4,
#  'maxweight': 12,
#  'maxwidth': 3,
#  'memorial': 2,
#  'military': 1,
#  'minspeed': 5,
#  'mofa': 1,
#  'moped': 21,
#  'moped:backward': 3,
#  'moped:forward': 2,
#  'motor_vehicle': 210,
#  'motor_vehicle:backward': 3,
#  'motor_vehicle:conditional': 1,
#  'motor_vehicle:forward': 3,
#  'motorboat': 4,
#  'motorcar': 29,
#  'motorcycle': 47,
#  'motorcycle:backward': 3,
#  'motorcycle:forward': 2,
#  'motorhome': 1,
#  'motorroad': 68,
#  'mtb:scale': 112,
#  'mtb:scale:imba': 1,
#  'mtb:scale:uphill': 8,
#  'name': 9505,
#  'name:botanical': 2,
#  'name:de': 2,
#  'name:en': 1,
#  'name:es': 3,
#  'name:it': 14,
#  'name:ja': 14,
#  'name:ko': 1,
#  'name:left': 55,
#  'name:lmo': 1,
#  'name:right': 52,
#  'name:zh': 2,
#  'narrow': 2,
#  'nat_ref': 32,
#  'natural': 374,
#  'noaddress': 1,
#  'noexit': 137,
#  'noname': 5,
#  'note': 247,
#  'note:access': 5,
#  'note:it': 7,
#  'note:lanes': 2,
#  'note:name': 5,
#  'note:parking': 1,
#  'note:ref': 1,
#  'note:source': 2,
#  'note:surface': 1,
#  'office': 15,
#  'official_name': 6,
#  'official_ref': 9,
#  'old_name': 90,
#  'old_ref': 86,
#  'oneway': 6453,
#  'oneway:bicycle': 7,
#  'oneway:bus': 2,
#  'oneway:foot': 2,
#  'oneway:moped': 3,
#  'oneway:motorcycle': 3,
#  'oneway:psv': 3,
#  'oneway:taxi': 3,
#  'opening_hours': 34,
#  'operator': 134,
#  'operator:ref': 4,
#  'operator:type': 4,
#  'overtaking': 73,
#  'owner': 1,
#  'park_ride': 49,
#  'parking': 681,
#  'parking:condition:both': 25,
#  'parking:condition:both:residents': 13,
#  'parking:condition:left': 11,
#  'parking:condition:left:residents': 5,
#  'parking:condition:left:time_interval': 1,
#  'parking:condition:left:vehicles': 2,
#  'parking:condition:right': 11,
#  'parking:condition:right:default': 1,
#  'parking:condition:right:residents': 6,
#  'parking:condition:right:time_interval': 2,
#  'parking:lane:both': 55,
#  'parking:lane:left': 29,
#  'parking:lane:right': 35,
#  'passenger': 2,
#  'passenger_information_display': 1,
#  'passenger_lines': 61,
#  'passing_places': 8,
#  'path': 1,
#  'payment:american_express': 1,
#  'payment:coins': 1,
#  'payment:mastercard': 1,
#  'payment:visa': 1,
#  'phone': 65,
#  'pipeline': 4,
#  'place': 14,
#  'platform': 1,
#  'platforms': 2,
#  'population': 1,
#  'postal_code': 231,
#  'power': 138,
#  'produce': 1,
#  'proposed': 19,
#  'province:left': 12,
#  'province:right': 12,
#  'psv': 76,
#  'psv:backward': 10,
#  'psv:forward': 1,
#  'psv:lanes': 2,
#  'public_transport': 39,
#  'quantity': 1,
#  'railway': 937,
#  'ramp': 5,
#  'ramp:bicycle': 2,
#  'ramp:stroller': 1,
#  'ramp:wheelchair': 3,
#  'recycling:batteries': 1,
#  'recycling:books': 2,
#  'recycling:cans': 1,
#  'recycling:cardboard': 1,
#  'recycling:cartons': 2,
#  'recycling:clothes': 1,
#  'recycling:electrical_appliances': 2,
#  'recycling:glass': 2,
#  'recycling:glass_bottles': 2,
#  'recycling:green_waste': 2,
#  'recycling:magazines': 2,
#  'recycling:newspaper': 2,
#  'recycling:paper': 2,
#  'recycling:paper_packaging': 2,
#  'recycling:plastic': 2,
#  'recycling:plastic_bottles': 2,
#  'recycling:plastic_packaging': 2,
#  'recycling:scrap_metal': 2,
#  'recycling:small_appliances': 2,
#  'recycling:waste': 1,
#  'recycling:wood': 2,
#  'recycling_type': 8,
#  'ref': 780,
#  'ref:mise': 4,
#  'ref:terna': 13,
#  'ref:terna:codice': 5,
#  'ref:vatin': 10,
#  'reg_name': 5,
#  'religion': 93,
#  'roof:colour': 7,
#  'roof:height': 2,
#  'roof:levels': 9,
#  'roof:material': 5,
#  'roof:orientation': 1,
#  'roof:shape': 15,
#  'rooms': 3,
#  'roundabout': 1,
#  'ruins': 2,
#  'sac_scale': 11,
#  'sd_fer_fon': 8,
#  'sd_fer_sed': 8,
#  'segregated': 143,
#  'self_service': 1,
#  'service': 1876,
#  'share_taxi': 1,
#  'shelter': 6,
#  'shop': 92,
#  'short_name': 106,
#  'sidewalk': 425,
#  'sidewalk:surface': 1,
#  'site_type': 1,
#  'ski': 4,
#  'smoking': 9,
#  'smoothness': 8,
#  'snowmobile': 3,
#  'social_facility': 2,
#  'social_facility:for': 1,
#  'source': 2737,
#  'source:access': 3,
#  'source:area': 2,
#  'source:bridge': 2,
#  'source:capacity': 3,
#  'source:covered': 1,
#  'source:ge': 1,
#  'source:geometry': 48,
#  'source:hgv': 1,
#  'source:lit': 1,
#  'source:maxspeed': 65,
#  'source:name': 28,
#  'source:oneway': 6,
#  'source:surface': 2,
#  'source:tunnel': 4,
#  'source:width': 1,
#  'species': 2,
#  'sport': 427,
#  'st_length_': 3,
#  'stars': 10,
#  'start_date': 49,
#  'start_date:name': 1,
#  'stay': 2,
#  'step_count': 46,
#  'steps': 1,
#  'stop': 12,
#  'substation': 30,
#  'subway': 1,
#  'supervised': 50,
#  'surface': 3281,
#  'surface:sidewalk': 2,
#  'surface_bike': 106,
#  'surveillance': 3,
#  'surveillance:type': 1,
#  'surveillance:zone': 1,
#  'survey_date': 5,
#  'tactile_paving': 6,
#  'takeaway': 2,
#  'taxi': 16,
#  'taxi:backward': 3,
#  'taxi:forward': 2,
#  'toll': 84,
#  'tourism': 38,
#  'tourist_bus': 1,
#  'tower:type': 10,
#  'tracks': 38,
#  'tracktype': 445,
#  'traffic_calming': 12,
#  'trail_visibility': 20,
#  'tram': 15,
#  'tram:backward': 3,
#  'trolley_wire': 67,
#  'trolley_wire:backward': 1,
#  'tunnel': 775,
#  'tunnel:name': 3,
#  'turn': 1,
#  'turn:lanes': 4,
#  'turn:lanes:backward': 2,
#  'turn:lanes:forward': 3,
#  'type': 1,
#  'url': 1,
#  'usage': 129,
#  'vehicle': 33,
#  'vehicle:conditional': 12,
#  'voltage': 686,
#  'water': 17,
#  'waterway': 1244,
#  'website': 65,
#  'wetland': 1,
#  'wheelchair': 79,
#  'wheelchair_toilet': 2,
#  'width': 118,
#  'wikidata': 5,
#  'wikipedia': 91,
#  'wires': 8,
#  'wood': 12}

# %%
### TAGS TYPE

"""
Here we can have the count of each of four tag categories in a dictionary to check the
"k" value for each "<tag>" and see if there are any potential problems.:
  "lower", for tags that contain only lowercase letters and are valid,
  "lower_colon", for otherwise valid tags with a colon in their names,
  "problemchars", for tags with problematic characters, and
  "other", for other tags that do not fall into the other three categories.
See the 'process_map' and 'test' functions for examples of the expected format.
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        k = element.attrib['k']
        if re.search(lower, k):
            keys["lower"] = keys["lower"] + 1
        elif re.search(lower_colon, k):
            keys["lower_colon"] = keys["lower_colon"] + 1
        elif re.search(problemchars, k):
            keys["problemchars"] = keys["problemchars"] + 1
        else:
             keys["other"] = keys["other"] + 1
        pass
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys



def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertion below will be incorrect then.
    # Note as well that the test function here is only used in the Test Run;
    # when you submit, your code will be checked against a different dataset.
    keys = process_map('Milano.osm')
    pprint.pprint(keys)


if __name__ == "__main__":
    test()
# Out:
# {'lower': 143750, 'lower_colon': 23813, 'other': 2097, 'problemchars': 0}

# %%
### EXPLORING USERS

"""
Find out how many unique users
have contributed to the map in this particular area!

The function process_map should return a set of unique user IDs ("uid")
"""

def get_user(element):
    return


def process_map(filename):
    users = set()
    for user, element in ET.iterparse(filename):
        if element.tag == "node":
           users.add(element.attrib['uid'])
        elif element.tag == "way": 
              users.add(element.attrib['uid'])
        elif element.tag == "relation": 
             users.add(element.attrib['uid'])    
        pass

    return users


def test():

    users = process_map('Milano.osm')
    pprint.pprint(len(users))
    
if __name__ == "__main__":
    test()
# Out:
# 1373

# %%
### EXPLORING STREET NAMES USING SAMPLE FILE

"""
Find out how many street we have
"""

osm_file = open("Milano.osm", "r")

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()

        street_types[street_type] += 1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street") 
    
    
def audit():
    for event, elem in ET.iterparse(osm_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])    
    print_sorted_dict(street_types)    

if __name__ == '__main__':
    audit()
# Out:
# 121: 1
# 23°: 1
# Abba: 2
# Abbadesse: 1
# Abruzzi: 4
# Acacie: 1
# Acqualunga: 4
# Adamello: 7
# Adda: 9
# Addetta: 1
# Adige: 8
# Adria: 1
# Adua: 4
# Affori: 1
# Africa: 1
# Agadir: 1
# Agnesi: 1
# Agostoni: 1
# Agrate: 2
# Agreste: 1
# Aguilhon: 1
# Aicardo: 1
# Aires: 4
# Airolda: 1
# Airolo: 1
# Alba: 1
# Albertis: 1
# Alberto: 7
# Aldina: 5
# Aleardi: 1
# Alemanni: 2
# Alessandrina: 1
# Alfieri: 12
# Alfonsine: 2
# Alighieri: 31
# Aliprandi: 4
# Allegranza: 1
# Allegri: 1
# Allende: 1
# Alpi: 1
# Alpine: 1
# Alpini: 4
# Alserio: 3
# Amadeo: 2
# Amati: 5
# Amedeo: 1
# Amendola: 7
# Amiata: 1
# Amicis: 8
# Ampère: 6
# Andegari: 2
# Andreani: 1
# Andreoli: 1
# Angelico: 2
# Annone: 1
# Annoni: 5
# Ansaloni: 1
# Ansperto: 1
# Antico: 10
# Antonini: 1
# Aosta: 2
# Aporti: 1
# Appennini: 2
# Appiani: 5
# Aprica: 1
# aprile: 1
# Aprile: 13
# Aquileia: 2
# Arbe: 5
# Archimede: 5
# Ardigò: 2
# Arese: 2
# Arezzo: 1
# Argelati: 1
# Argonne: 1
# Ariosto: 6
# Aristotele: 6
# Arno: 6
# Arona: 1
# Arosio: 1
# Arsizio: 1
# artigiani: 1
# Arzaga: 1
# Aselli: 2
# Asiago: 4
# Aspromonte: 3
# Assunta: 2
# Astesani: 3
# Asti: 1
# Astolfo: 1
# Aulenti: 3
# Aurispa: 1
# Ausonio: 1
# Avogadro: 1
# Azalee: 1
# Babila: 3
# Bach: 1
# Bachelet: 1
# Baggio: 1
# Baiamonti: 1
# Balconi: 2
# Baldanza: 2
# Baldinucci: 1
# Baldironi: 1
# Balfredo: 1
# Bandiera: 1
# Baracca: 7
# Barbavara: 1
# Barbieri: 2
# Barellai: 1
# Barona: 1
# Baroni: 5
# Barozzi: 1
# Barro: 1
# Bartolomeo: 2
# Barzini: 2
# Barzoni: 1
# Bassi: 5
# Bassini: 2
# Bastia: 1
# Battisti: 15
# Beccalzù: 1
# Beccaria: 4
# Begonie: 1
# Belinzaghi: 1
# Bellani: 2
# Bellaria: 2
# Bellini: 12
# bellini: 1
# Bellone: 2
# Belloni: 1
# Belluno: 1
# Belvedere: 3
# Bembo: 3
# Benaco: 1
# Benessere: 2
# Benini: 1
# Berchet: 1
# Beretta: 1
# Bergamina: 1
# Bergamo: 8
# Berlese: 1
# Berlinguer: 2
# Bernardo: 2
# Bernini: 3
# Berra: 1
# Bertacchi: 1
# Bertelli: 2
# Bertoni: 1
# Vercelli: 3
# Vercesi: 3
# Verdi: 21
# Verga: 3
# Vergani: 1
# Verità: 1
# Verme: 2
# Veronese: 2
# Verri: 4
# Verrocchio: 1
# Vespucci: 6
# Vezzoli: 1
# Vico: 1
# Vida: 1
# Vignazza: 1
# Vigorelli: 1
# Villa: 11
# Villora: 2
# Villoresi: 1
# Vimercate: 1
# Vimercati: 1
# Vincenzo: 1
# Vinci: 27
# Viole: 1
# Viollier: 4
# Virgilio: 3
# Visconti: 4
# Viscontini: 1
# Vito: 1
# Vitruvio: 4
# Vittore: 1
# Vittoria: 9
# Vittorio: 12
# Vivaio: 6
# Vivaldi: 1
# Viviani: 1
# Volonteri: 2
# Volpi: 2
# Volta: 34
# Voltri: 1
# Volturno: 22
# Wagner: 1
# Washington: 2
# Wildt: 1
# XXIII: 12
# Zamparelli: 1
# Zanata: 1
# Zandonai: 1
# Zanella: 3
# Zanzi: 1
# Zara: 5
# Zavattari: 1
# Zebedia: 1
# Zeuner: 1
# Zinie: 2
# Zuavi: 1
# Zucchetta: 1
# Zucchi: 14
# Zuccoli: 1
# Zugna: 2

# %%
### EXPLORING BUILDINGS TYPES USING SAMPLE FILE

"""
Find out how many type of buildings we have
"""

osm_file = open("Milano.osm", "r")

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()

        street_types[street_type] += 1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "building") 
    
    
def audit():
    for event, elem in ET.iterparse(osm_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])    
    print_sorted_dict(street_types)    

if __name__ == '__main__':
    audit()
# Out:
# abandoned: 1
# apartments: 1986
# barn: 5
# bridge: 1
# castle: 1
# chapel: 3
# church: 64
# civic: 10
# collapsed: 7
# commercial: 158
# construction: 10
# cowshed: 2
# damaged: 1
# depot: 1
# detached: 19
# farm: 43
# farm_auxiliary: 15
# fire_station: 1
# garage: 206
# garages: 168
# garges: 1
# generic: 1
# grandstand: 8
# greenhouse: 12
# gym: 5
# hangar: 6
# hospital: 12
# hotel: 11
# house: 2053
# hut: 2
# industrial: 944
# kindergarten: 11
# kiosk: 11
# manufacture: 1
# military: 1
# monastery: 1
# office: 69
# parish: 8
# parking: 1
# pavilion: 1
# platform: 1
# prison: 1
# public: 18
# residential: 1379
# restaurant: 1
# retail: 62
# Rho: 1
# roof: 169
# sally_port: 1
# school: 89
# service: 131
# shed: 59
# shelter: 4
# stable: 2
# stadium: 1
# supermarket: 3
# tank: 3
# terrace: 107
# tower: 2
# train_station: 10
# transformer_tower: 1
# university: 10
# utility: 3
# villa: 5
# warehouse: 21
# wayside_shrine: 2
# window: 1
# yes: 14100

# %%
### EXPLORING BUILDINGS TYPES USING SAMPLE FILE

"""
Find out how many type of buildings we have
"""

osm_file = open("Milano.osm", "r")

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()

        street_types[street_type] += 1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "brand") 
    
    
def audit():
    for event, elem in ET.iterparse(osm_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])    
    print_sorted_dict(street_types)    

if __name__ == '__main__':
    audit()
# Out:
# @pump: 1
# Agesp: 1
# Agip: 8
# api: 2
# Aprilia: 1
# Auchan: 1
# Audi: 1
# BCC: 1
# Beghelli: 1
# Bergamasco: 1
# BNL: 1
# Brums: 1
# cioccolato: 1
# DR: 1
# Easy: 1
# Enel: 2
# Eni: 7
# ERG: 4
# Erg: 2
# Esso: 7
# Farmacia: 1
# glass: 1
# Honda: 1
# Independent: 1
# IP: 7
# Keropetrol: 1
# Lidl: 1
# Lillapois: 1
# Mazda: 1
# Mercedes: 1
# Mistubishi: 1
# Oil: 1
# Opel: 1
# Peugeot: 2
# Puff: 1
# Q8: 6
# Q8easy: 2
# Retitalia: 1
# Romeo: 1
# Shell: 11
# store: 1
# Tamoil: 10
# Tecnorete: 1
# TIM: 1
# Tim: 1
# Total: 6
# TotalErg: 2
# Unes: 1
# Vodafone: 1
# West: 1
# Yamaha: 1

# %%
###Improving Street Names, building types and brand on the original file
"""
- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""


OSMFILE = "Milano.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

        
expected = ["Aprile", "Bellini", "XXIII", "121 Pobbiano - Agrate", "garage", "Api", "TotalErg", "Q8easy", "Tim"]

mapping = { "aprile": "Aprile",
            "bellini": "Bellini",
            "Ave" : "",
            "23°" : "XXIII",
            "121" : "121 Pobbiano - Agrate",
            "garages" : "garage",
            "garges" : "garage",
            "api" : "Api",
            "TIM" : "Tim",
            "Erg" : "TotalErg",
            "Easy" : "Q8easy"
            }
    
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street" or elem.attrib['k'] == "building" or elem.attrib['k'] == "brand")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types


def update_name(name, mapping):
    
    n = street_type_re.search(name)
    
    if n.group() in mapping.keys():
        if n not in expected:
            name = re.sub(n.group(), mapping[n.group()], name)
    return name


def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            if name == "aprile":
                assert better_name == "Aprile"
            if name == "Erg":
                assert better_name == "TotalErg"


if __name__ == '__main__':
    test()
# Out:
# {'121': set(['Strada Provinciale 121']),
#  'Abba': set(['Via Giuseppe Cesare Abba']),
#  'Abbadesse': set(['Via Abbadesse']),
#  'Abruzzi': set(['Viale Abruzzi']),
#  'Acacie': set(['Via delle Acacie']),
#  'Acqualunga': set(['Via Acqualunga']),
#  'Adamello': set(['Via Adamello']),
#  'Adda': set(['Via Adda', 'Via Fiume Adda']),
#  'Addetta': set(['Viale Addetta']),
#  'Adige': set(['Via Adige']),
#  'Adria': set(['Via Adria']),
#  'Adua': set(['Via Adua']),
#  'Affori': set(['Viale Affori']),
#  'Africa': set(['Via Africa']),
#  'Agadir': set(['Via Agadir']),
#  'Agesp': set(['Agesp']),
#  'Agip': set(['Agip']),
#  'Agnesi': set(['Via Gaetana Agnesi']),
#  'Agostoni': set(['Via Angelo Agostoni']),
#  'Agrate': set(['SP 121 Pobbiano - Agrate']),
#  'Agreste': set(['Via Agreste']),
#  'Aguilhon': set(['Via Cesare Aguilhon']),
#  'Aicardo': set(['Via Aicardo']),
#  'Aires': set(['Corso Buenos Aires', 'Galleria Buenos Aires']),
#  'Airolo': set(['Via Airolo']),
#  'Alba': set(['Vicolo Alba']),
#  'Albertis': set(['Via Sebastiano de Albertis']),
#  'Alberto': set(['Via Carlo Alberto']),
#  'Aldina': set(['Via Aldina']),
#  'Aleardi': set(['Via Aleardo Aleardi']),
#  'Alemanni': set(['Via Alemanni']),
#  'Alessandrina': set(['Via Alessandrina']),
#  'Alfieri': set(['Via Vittorio Alfieri']),
#  'Alfonsine': set(['Via Alfonsine']),
#  'Alighieri': set(['Galleria Dante Alighieri', 'Via Dante Alighieri']),
#  'Aliprandi': set(['Via Pinalla Aliprandi']),
#  'Allegranza': set(['Via Giuseppe Allegranza']),
#  'Allende': set(['Via Salvador Allende']),
#  'Alpi': set(['Via Alpi']),
#  'Alpine': set(['Via delle Stelle Alpine']),
#  'Alpini': set(['Via degli Alpini']),
#  'Alserio': set(['Via Alserio']),
#  'Amadeo': set(['Via Giovanni Antonio Amadeo']),
#  'Amati': set(['Via Carlo Amati']),
#  'Amendola': set(['Piazza Giovanni Amendola', 'Via Giovanni Amendola']),
#  'Amiata': set(['Via Monte Amiata']),
#  'Amicis': set(['Via Edmondo De Amicis']),
#  u'Amp\xe8re': set([u'Via Andrea Maria Amp\xe8re']),
#  'Andegari': set(['Via Andegari']),
#  'Andreani': set(['Via Paolo Andreani']),
#  'Andreoli': set(['Via Don Giuseppe Andreoli']),
#  'Angelico': set(['Via Beato Angelico']),
#  'Annone': set(['Via Annone']),
#  'Annoni': set(['Via Gaetano Annoni']),
#  'Ansaloni': set(['Via Ansaloni']),
#  'Ansperto': set(['Via Ansperto']),
#  'Antico': set(['Via Comune Antico', 'Via Pozzo Antico']),
#  'Antonini': set(['Via Giacomo Antonini']),
#  'Aosta': set(['Via Aosta']),
#  'Aporti': set(['Via Ferrante Aporti']),
#  'Appennini': set(['Via Appennini']),
#  'Appiani': set(['Via Andrea Appiani']),
#  'Aprica': set(['Via Aprica']),
#  'Aprilia': set(['Aprilia']),
#  'Aquileia': set(['Piazzale Aquileia', 'Via Aquileia']),
#  'Arbe': set(['Via Arbe']),
#  'Archimede': set(['Via Archimede']),
#  u'Ardig\xf2': set([u'Via Roberto Ardig\xf2']),
#  'Arese': set(['Via Francesco Arese']),
#  'Arezzo': set(['Via Arezzo']),
#  'Argelati': set(['Via Filippo Argelati']),
#  'Argonne': set(['Viale Argonne']),
#  'Ariosto': set(['Via Lodovico Ariosto', 'Via Ludovico Ariosto']),
#  'Aristotele': set(['Via Aristotele']),
#  'Arno': set(['Via Arno']),
#  'Arona': set(['Via Arona']),
#  'Arosio': set(['Via Enrico Arosio']),
#  'Arsizio': set(['Via Busto Arsizio']),
#  'Arzaga': set(['Via Arzaga']),
#  'Aselli': set(['Via Gaspare Aselli']),
#  'Asiago': set(['Via Asiago']),
#  'Aspromonte': set(['Piazza Aspromonte', 'Via Aspromonte']),
#  'Assunta': set(['viale Assunta']),
#  'Astesani': set(['Via Alessandro Astesani']),
#  'Asti': set(['Via privata Asti']),
#  'Astolfo': set(['Via Astolfo']),
#  'Auchan': set(['Auchan']),
#  'Audi': set(['Audi']),
#  'Aulenti': set(['Piazza Gae Aulenti']),
#  'Aurispa': set(['Via Giovanni Aurispa']),
#  'Ausonio': set(['Via Ausonio']),
#  'Avogadro': set(['Via privata Gerolamo Avogadro']),
#  'Azalee': set(['Via Azalee']),
#  'BCC': set(['BCC']),
#  'BNL': set(['BNL']),
#  'Babila': set(['Galleria San Babila', 'Piazza San Babila']),
#  'Bach': set(['Via Johan Sebastian Bach']),
#  'Bachelet': set(['Via Vittorio Bachelet']),
#  'Baggio': set(['Strada per Baggio']),
#  'Baiamonti': set(['Piazzale Antonio Baiamonti']),
#  'Balconi': set(['Via Giacomo Balconi']),
#  'Baldanza': set(['Via Liborio Baldanza', 'Vicolo Liborio Baldanza']),
#  'Baldinucci': set(['Via Filippo Baldinucci']),
#  'Baldironi': set(['Via Gerolamo Baldironi']),
#  'Balfredo': set(['Via Balfredo']),
#  'Bandiera': set(['Via Fratelli Bandiera']),
#  'Baracca': set(['Via Francesco Baracca']),
#  'Barbavara': set(['Via Barbavara']),
#  'Barbieri': set(['Via Salvatore Barbieri']),
#  'Barellai': set(['Via Giuseppe Barellai']),
#  'Barona': set(['Via Barona']),
#  'Baroni': set(['Via Costantino Baroni']),
#  'Barozzi': set(['Via Michele Barozzi']),
#  'Barro': set(['Via Monte Barro']),
#  'Bartolomeo': set(['Via Fra Bartolomeo', 'Via San Bartolomeo']),
#  'Barzini': set(['Via privata Luigi Barzini']),
#  'Barzoni': set(['Via Vittorio Barzoni']),
#  'Bassi': set(['Via Ugo Bassi']),
#  'Bassini': set(['Via Edoardo Bassini']),
#  'Bastia': set(['Via Privata Bastia']),
#  'Battisti': set(['Via Cesare Battisti', 'Viale Cesare Battisti']),
#  u'Beccalz\xf9': set([u'Via Frazione Beccalz\xf9']),
#  'Beccaria': set(['Via Cesare Beccaria']),
#  'Beghelli': set(['Beghelli']),
#  'Begonie': set(['Via delle Begonie']),
#  'Belinzaghi': set(['Via Giulio Belinzaghi']),
#  'Bellani': set(['Vicolo Angelo Bellani']),
#  'Bellaria': set(['Via Bellaria', 'Via Cascina Bellaria']),
#  'Bellone': set(['Via Carlo Bellone']),
#  'Belloni': set(['Via Angelo Belloni']),
#  'Belluno': set(['Via Belluno']),
#  'Belvedere': set(['Via Belvedere']),
#  'Bembo': set(['Via Pietro Bembo']),
#  'Benaco': set(['Via Benaco']),
#  'Benessere': set(['Viale Benessere']),
#  'Benini': set(['Via Vincenzo Benini']),
#  'Berchet': set(['Via Giovanni Berchet']),
#  'Beretta': set(['Via Angelindo Barzago e Angelo Beretta']),
#  'Bergamasco': set(['Credito Bergamasco']),
#  'Bergamina': set(['Via Bergamina']),
#  'Bergamo': set(['Via Bergamo']),
#  'Berlese': set(['Via Antonio Berlese']),
#  'Berlinguer': set(['Via Enrico Berlinguer']),
#  'Bernardo': set(['Via San Bernardo']),
#  'Bernini': set(['Via Gian Lorenzo Bernini']),
#  'Berra': set(['Via Don Berra']),
#  'Bertacchi': set(['Via Giovanni Bertacchi']),
#  'Bertelli': set(['Via Luigi Bertelli']),
#  'Bertoni': set(['Via Renzo Bertoni']),
#  'Beruto': set(['Via Cesare Beruto']),
#  'Besozzi': set(['Via Carlo Besozzi']),
#  'Besozzo': set(['Via Michelino da Besozzo']),
#  'Bestazzo': set(['Via Bestazzo']),
#  'Betti': set(['Via Ugo Betti']),
#  'Bezzecca': set(['Via Bezzecca']),
#  'Bianche': set(['Via Torri Bianche']),
#  u'Bianchi': set(["Via Giuseppe Piolti De' Bianchi",
#                   u'Via Mos\xe8 Bianchi',
#                   'via Don Giacomo Bianchi']),
#  'Bianco': set(['Via Monte Bianco']),
#  'Bigli': set(['Via Bigli']),
#  'Bindellera': set(['Via Bindellera']),
#  'Biraghi': set(['Piazza Oreste Biraghi', 'Via Luigi Biraghi']),
#  'Birolli': set(['Via privata Renato Birolli']),
#  'Birona': set(['Via della Birona']),
#  'Bissolati': set(['Via Leonida Bissolati']),
#  u'Biul\xe8': set([u'via salita al Biul\xe8']),
#  'Bixio': set(['Via Nino Bixio']),
#  'Bligny': set(['Viale Bligny']),
#  'Bo': set(['Via Carlo Bo']),
#  'Boccaccio': set(['Via Giovanni Boccaccio']),
#  'Boccioni': set(['Via Umberto Boccioni']),
#  'Boito': set(['Via Arrigo Boito']),
#  'Boltraffio': set(['Via Gian Antonio Boltraffio']),
#  'Bolzano': set(['Via Bolzano']),
#  'Bonaparte': set(['Via Napoleone Bonaparte']),
#  'Bonfadini': set(['Via Romualdo Bonfadini']),
#  'Bonnet': set(['Via privata Nino Bonnet']),
#  'Bordoni': set(['Via Antonio Bordoni']),
#  'Borella': set(['Piazza don Giuseppe Borella']),
#  'Borgazzi': set(['Via Gerolamo Borgazzi']),
#  'Borgese': set(['Via Giuseppe Antonio Borgese']),
#  'Borghetto': set(['Via Borghetto', 'Vicolo Borghetto']),
#  'Borgogna': set(['Via Borgogna']),
#  'Borgonuovo': set(['Via Borgonuovo']),
#  'Borgospesso': set(['Via Borgospesso']),
#  'Borromei': set(['Via Borromei']),
#  'Borromeo': set(['Via San Carlo Borromeo']),
#  'Borsa': set(['Via Emilio Borsa']),
#  'Borsieri': set(['Via Pietro Borsieri']),
#  'Boscaiola': set(['Via della Boscaiola']),
#  'Boschetto': set(['Via Boschetto']),
#  'Bosco': set(['Via San Giovanni Bosco']),
#  'Boscovich': set(['Via Ruggero Boscovich']),
#  'Botta': set(['Via Carlo Botta']),
#  'Bottelli': set(['Via Giuseppe Bottelli']),
#  'Bottesini': set(['Via Giovanni Bottesini']),
#  'Botticelli': set(['Via Sandro Botticelli']),
#  'Bottini': set(['Piazza Enrico Bottini']),
#  'Bottoni': set(['Via Piero Bottoni']),
#  'Bovisasca': set(['Via Bovisasca']),
#  'Bragadino': set(['Via Marco Antonio Bragadino']),
#  'Bragosa': set(['C.na Bragosa', 'Cascina Bragosa']),
#  'Bramante': set(['Via Bramante']),
#  'Brasile': set(['Via Brasile']),
#  'Breda': set(['Via Ernesto Breda']),
#  'Brembo': set(['Via Brembo']),
#  'Breme': set(['Via Ludovico di Breme']),
#  'Brennero': set(['Via Brennero']),
#  'Brera': set(['Via Brera']),
#  'Brescia': set(['Piazzale Brescia', 'Via Arnaldo da Brescia', 'Via Brescia']),
#  'Briantina': set(['Via Briantina']),
#  'Brianza': set(['Via Brianza', 'Viale Brianza']),
#  'Briosi': set(['Via Giovanni Briosi']),
#  'Brisa': set(['Via Brisa']),
#  'Brocchi': set(['Via Gian Battista Brocchi']),
#  'Brodolini': set(['Via Brodolini', 'Via Giacomo Brodolini']),
#  'Broggi': set(['Via Giuseppe Broggi']),
#  'Broletto': set(['Via Broletto']),
#  'Broni': set(['Via Broni']),
#  'Bronzino': set(['Via Bronzino']),
#  'Brugallo': set(['Via Brugallo']),
#  'Brughiere': set(['Via delle Brughiere']),
#  'Brums': set(['Brums']),
#  'Brunelleschi': set(['Via Filippo Brunelleschi']),
#  'Brunetti': set(['Via Angelo Brunetti']),
#  'Bruno': set(['Via Giordano Bruno']),
#  'Brunone': set(['Piazza San Brunone']),
#  'Bruschetti': set(['Via Giuseppe Bruschetti']),
#  'Bruto': set(['Via Marco Bruto']),
#  'Bruxelles': set(['Via Bruxelles']),
#  'Buccari': set(['Via Buccari']),
#  'Budrio': set(['Via Budrio']),
#  'Budua': set(['Via Budua']),
#  'Buffoli': set(['Viale Luigi Buffoli']),
#  'Bugatti': set(['Via privata Gaspare Bugatti']),
#  'Buonaparte': set(['Foro Buonaparte']),
#  'Buonarroti': set(['Via Michelangelo Buonarroti']),
#  'Buozzi': set(['Via Bruno Buozzi']),
#  'Burigozzo': set(['Via Marco Burigozzo']),
#  'Buschi': set(['Via Averardo Buschi']),
#  'Bussero': set(['Via Uberto da Bussero']),
#  'Caboto': set(['Via Giovanni Caboto']),
#  'Cadore': set(['Via Cadore']),
#  'Cadorna': set(['Piazzale Luigi Cadorna',
#                  'Via Cadorna',
#                  'Via Luigi Cadorna']),
#  'Cagliero': set(['Via Giovanni Cagliero']),
#  'Cagni': set(['Via Umberto Cagni']),
#  'Caimi': set(['Via Giuseppe Caimi']),
#  'Cairoli': set(['Via Cairoli', 'Via Fratelli Cairoli']),
#  'Cajani': set(['Via Maria Cajani']),
#  'Calabria': set(['Via Don Giovanni Calabria']),
#  'Calatafimi': set(['Via Calatafimi']),
#  'Calcutta': set(['Via Madre Teresa di Calcutta']),
#  'Caldara': set(['Viale Emilio Caldara']),
#  'California': set(['Via California']),
#  'Calimero': set(['Via San Calimero']),
#  'Callas': set(['Largo Maria Callas']),
#  'Calori': set(['Via Luigi Calori']),
#  'Calvi': set(['Via Pietro Calvi']),
#  'Calvino': set(['Via Giovanni Calvino', 'Via Italo Calvino']),
#  'Cambiaghi': set(['Piazza Giuseppe Cambiaghi']),
#  'Camelie': set(['Via Camelie']),
#  'Campanella': set(['Via Tommaso Campanella']),
#  'Campania': set(['Via Campania', 'Viale Campania']),
#  'Campanile': set(['Vicolo Campanile']),
#  'Campanini': set(['Via Alfredo Campanini']),
#  'Campari': set(['Via Davide Campari']),
#  'Camperio': set(['Via Fratelli Camperio', 'Via Manfredo Camperio']),
#  'Campestre': set(['Via Campestre']),
#  'Campiglio': set(['Via Ambrogio Campiglio']),
#  'Canaletto': set(['Via Canaletto']),
#  'Candiani': set(['Via Giuseppe Candiani']),
#  'Canegrate': set(['Via per Canegrate']),
#  'Cannobio': set(['Via Paolo da Cannobio']),
#  'Canonica': set(['Via Luigi Canonica']),
#  'Canova': set(['Via Antonio Canova']),
#  'Cantalupo': set(['Via Cantalupo']),
#  'Cantoni': set(['Via Ermenegildo Cantoni']),
#  'Cantore': set(['Via Antonio Cantore']),
#  u'Cant\xf9': set([u'Via Cesare Cant\xf9']),
#  'Capelli': set(['Via Vincenzo Capelli']),
#  'Capitani': set(['Via De Capitani']),
#  'Capolago': set(['Via Privata Capolago']),
#  'Cappuccina': set(['Via Cappuccina']),
#  'Cappuccini': set(['Via dei Cappuccini']),
#  'Capranica': set(['Via Luigi Capranica']),
#  'Caprera': set(['Via Caprera']),
#  'Caprifoglio': set(['Via Caprifoglio']),
#  'Capuana': set(['Via Luigi Capuana']),
#  'Caracciolo': set(['Via Francesco Caracciolo']),
#  'Caravaggio': set(['Via Caravaggio', 'Via Polidoro da Caravaggio']),
#  'Carbonera': set(['Via Azzo Carbonera']),
#  'Carcano': set(['Via Filippo Carcano', 'Via Giulio Carcano']),
#  u'Carducci': set([u'Piazza Giosu\xe8 Carducci', u'Via Giosu\xe8 Carducci']),
#  'Caretta': set(['Via Annibale Caretta']),
#  'Caretto': set(['Via Aminto Caretto']),
#  u'Carit\xe0': set([u'Strada della Carit\xe0']),
#  'Carldirera': set(['Via Carldirera']),
#  'Carli': set(['Via Gian Rinaldo Carli']),
#  'Carlo': set(['Via San Carlo']),
#  'Carnevali': set(['Via Antonio Carnevali']),
#  'Carnielli': set(['Piazza Don Piero Carnielli']),
#  'Caro': set(['Via Annibal Caro']),
#  'Caroccio': set(['Via del Caroccio']),
#  'Caronni': set(['Via Felice Caronni']),
#  'Caronti': set(['Via Filippo Caronti']),
#  'Carpaccio': set(['Via Carpaccio', 'Via Vittore Carpaccio']),
#  'Carpoforo': set(['Via San Carpoforo']),
#  'Carrara': set(['Piazza Francesco Carrara']),
#  'Carrobbio': set(['Via Carrobbio']),
#  'Carrobiolo': set(['Piazza Carrobiolo', 'Vicolo Carrobiolo']),
#  'Carroccio': set(['Piazza Carroccio', 'Via Carroccio']),
#  'Carso': set(['Via San Michele del Carso', 'Viale San Michele del Carso']),
#  'Caruso': set(['Via Enrico Caruso']),
#  'Casati': set(['Via Felice Casati', 'Via Gaetano Casati']),
#  'Cascella': set(['Via Pietro Cascella']),
#  'Cascine': set(['Via delle Cascine']),
#  'Casecca': set(['Via Casecca']),
#  'Casiraghi': set(['Viale Fratelli Casiraghi']),
#  'Cassala': set(['Viale Cassala']),
#  'Cassanese': set(['Via Cassanese']),
#  'Cassignolo': set(['Via Cassignolo']),
#  'Cassinari': set(['Via Bruno Cassinari']),
#  'Cassino': set(['Via Cassino']),
#  'Castelbarco': set(['Via Gian Carlo Castelbarco']),
#  'Castelfidardo': set(['Via Castelfidardo']),
#  'Castellanza': set(['Via Castellanza']),
#  'Castello': set(['Piazza Castello']),
#  'Castillia': set(['Via Gaetano De Castillia', 'Vicolo Gaetano De Castillia']),
#  'Castoldi': set(['Via Castoldi']),
#  'Caterina': set(['Vicolo Santa Caterina']),
#  'Cattaneo': set(['Via Carlo Cattaneo']),
#  'Catullo': set(['Via Catullo', 'Via privata Gaio Valerio Catullo']),
#  'Cavalcanti': set(['Via Cavalcanti', 'Via Guido Cavalcanti']),
#  'Cavalieri': set(['Via Bonaventura Cavalieri']),
#  'Cavallotti': set(['Via Felice Cavallotti']),
#  'Cavarott': set(['Via al Cavarott', 'via al Cavarott']),
#  'Caveto': set(['Via Caveto']),
#  'Caviglia': set(['Via Enrico Caviglia']),
#  'Cavour': set(['Piazza Cavour',
#                 'Via Camillo Benso Conte di Cavour',
#                 'Via Camillo Benso conte di Cavour',
#                 'Via Camillo Cavour',
#                 'Via Cavour',
#                 'Viale Camillo Benso Conte di Cavour']),
#  'Cazzaniga': set(['Via Angelo Cazzaniga', 'Via Paolo Cazzaniga']),
#  'Cechov': set(['Via Antonio Cechov']),
#  'Cederna': set(['Via Antonio Cederna']),
#  'Cefalonia': set(['Via Martiri di Cefalonia']),
#  u'Cefal\xf9': set([u'Via Privata Cefal\xf9']),
#  'Cellini': set(['Via Benvenuto Cellini']),
#  'Celoria': set(['Via Giovanni Celoria']),
#  'Cenisio': set(['Via Cenisio']),
#  'Cermenate': set(['Viale Giovanni da Cermenate']),
#  'Cernuschi': set(['Via Enrico Cernuschi']),
#  'Cernusco': set(['Via Pietro da Cernusco']),
#  'Certosa': set(['Viale Certosa']),
#  'Cervi': set(['Via Fratelli Cervi']),
#  'Cervignano': set(['Via Cervignano']),
#  'Cervino': set(['Via Monte Cervino']),
#  'Cevedale': set(['Via Cevedale']),
#  'Chiaravalle': set(['Via Chiaravalle']),
#  'Chiarelli': set(['Via Luigi Chiarelli']),
#  'Chiasserini': set(['Via Dante Chiasserini']),
#  'Chiesa': set(['Piazza della Chiesa',
#                 'Via Carlo Alberto dalla Chiesa',
#                 'Via Damiano Chiesa']),
#  'Chioggia': set(['Vicolo Chioggia']),
#  'Chiusi': set(['Via dei Chiusi']),
#  'Cialdini': set(['Via Cialdini']),
#  'Ciani': set(['Via privata Fratelli Ciani']),
#  'Cicerone': set(['Via Marco Tullio Cicerone']),
#  'Ciclamini': set(['Via dei Ciclamini']),
#  'Ciclamino': set(['Via Ciclamino']),
#  'Cicognara': set(['Via Leopoldo Cicognara']),
#  'Cilea': set(['Via Francesco Cilea']),
#  'Cimabue': set(['Via Giovanni Cimabue']),
#  'Cimitero': set(['Via dei Cimitero', 'Via del Cimitero']),
#  'Cimone': set(['Via Monte Cimone']),
#  'Cincinnato': set(['Piazza Cincinnato']),
#  'Ciniselli': set(['Via Ciniselli']),
#  'Cinisello': set(['Strada comunale per Cinisello', 'Strada per Cinisello']),
#  'Circonvallazione': set(['Via Circonvallazione']),
#  u'Ciri\xe8': set([u'Via Ciri\xe8']),
#  'Cittadini': set(['Via Pier Francesco Cittadini']),
#  'Citterio': set(['Piazza Gianni Citterio']),
#  'Civerchio': set(['Via Vincenzo Civerchio']),
#  'Civitali': set(['Via Matteo Civitali']),
#  'Clemente': set(['Via San Clemente']),
#  'Clotilde': set(['Piazzale Principessa Clotilde', 'Via Santa Clotilde']),
#  'Codara': set(['Via Giuseppe Codara']),
#  'Colletta': set(['Via Pietro Colletta']),
#  'Collodi': set(['Via Carlo Collodi']),
#  'Colnaghi': set(['Via don Carlo Colnaghi']),
#  'Colombo': set(['Via Cristoforo Colombo',
#                  'Via Giuseppe Colombo',
#                  'Via Luigi Colombo',
#                  'Viale Cristoforo Colombo']),
#  'Colonna': set(['Via Marco Antonio Colonna']),
#  'Columella': set(['Via Lucio Giunio Columella']),
#  'Colzani': set(['Via Livio Colzani']),
#  'Comandini': set(['Via Alfredo Comandini']),
#  'Combattenti': set(['Viale Combattenti']),
#  'Comelico': set(['Via Comelico']),
#  'Commerciale': set(['Piazza Centro Commerciale']),
#  'Commercio': set(['Via del Commercio']),
#  'Como': set(['Corso Como', 'Via Como']),
#  'Conchetta': set(['Via Conchetta']),
#  'Concliazione': set(['Piazza Concliazione']),
#  'Concordia': set(['Via Concordia']),
#  'Confalonieri': set(['Piazza Natale Confalonieri',
#                       'Via Federico Confalonieri']),
#  'Conservatorio': set(['Via Conservatorio']),
#  'Cooperazione': set(['Via Della Cooperazione', 'Viale Cooperazione']),
#  u'Copernico': set(['Via Copernico', u'Via Niccol\xf2 Copernico']),
#  'Coppi': set(['Via Fausto Coppi']),
#  'Cordusio': set(['Via Cordusio']),
#  'Cornalia': set(['Via Emilio Cornalia']),
#  'Cornate': set(['Via Per Cornate']),
#  'Cornicione': set(['Via al Cornicione']),
#  'Correggio': set(['Via Antonio Allegri Correggio']),
#  'Corridoni': set(['Via Filippo Corridoni']),
#  'Corsica': set(['Viale Corsica']),
#  'Cortelonga': set(['Via Cortelonga']),
#  'Corteselle': set(['Via Corteselle']),
#  'Corti': set(['Via Alfonso Corti']),
#  'Corticella': set(['Piazzetta Corticella']),
#  'Cortona': set(['Via Pietro da Cortona']),
#  'Cossa': set(['Via Pietro Cossa']),
#  'Costa': set(['Via Andrea Costa']),
#  'Costanza': set(['Via Costanza']),
#  'Cozzi': set(['Via Roberto Cozzi']),
#  'Crema': set(['Via Crema']),
#  'Crescenzago': set(['Via Crescenzago']),
#  'Crescitelli': set(['Via Alberico Crescitelli']),
#  'Crespi': set(['Largo Gian Battista Crespi', 'Via Benigno Crespi']),
#  'Crispi': set(['Via Francesco Crispi', 'Viale Francesco Crispi']),
#  'Cristoforis': set(['Via Carlo De Cristoforis']),
#  'Cristoforo': set(['Via San Cristoforo']),
#  'Croce': set(['Via Benedetto Croce', 'Via Croce', 'Via Santa Croce']),
#  'Cucchiari': set(['Via Domenico Cucchiari']),
#  'Cufra': set(['Via Cufra']),
#  'Cupello': set(['Via Cupello']),
#  'Curiel': set(['Via Curiel', 'Via Eugenio Curiel']),
#  'Curtatone': set(['Via Curtatone']),
#  'Cusani': set(['Via Cusani']),
#  "D'Acquisto": set(["Piazza Salvo D'Acquisto", "Via Salvo D'Acquisto"]),
#  "D'Ancona": set(["Via Stamira D'Ancona"]),
#  "D'Annunzio": set(["Via Gabriele D'Annunzio"]),
#  "D'Arnolfo": set(["Via Porta D'Arnolfo"]),
#  "D'Azeglio": set(["Via Massimo D'Azeglio"]),
#  "D'Intignano": set(["Via Luigi Mainoni D'Intignano"]),
#  "D'Ossola": set(["Via Val D'Ossola"]),
#  'DR': set(['DR']),
#  'Dalie': set(['Via delle Dalie']),
#  'Damiano': set(['Via San Damiano']),
#  'Danilo': set(['Via Privata Danilo']),
#  'Dante': set(['Via Dante']),
#  'Darwin': set(['Via Carlo Darwin', 'Via Darwin']),
#  'Deffenu': set(['Via Attilio Deffenu']),
#  'Deledda': set(['Via Grazia Deledda', 'Via Maria Grazia Deledda']),
#  'Depaolini': set(['Via Mario Re Depaolini']),
#  'Desiderio': set(['Via Desiderio']),
#  'Desio': set(['Via Desio']),
#  'Devoto': set(['Via Luigi Devoto']),
#  'Diaz': set(['Piazza Armando Diaz', 'Via Armando Diaz']),
#  'Dini': set(['Via Ulisse Dini']),
#  'Dio': set(['Via Fratelli di Dio']),
#  'Diocleziano': set(['Piazza Diocleziano']),
#  'Diomede': set(['Via Diomede']),
#  u'Doberd\xf2': set([u'Via Doberd\xf2']),
#  'Dolomiti': set(['Via Dolomiti']),
#  'Donatello': set(['Via Donatello']),
#  'Donegani': set(['Largo Guido Donegani']),
#  'Donizetti': set(['Via Gaetano Donizetti']),
#  'Dorderio': set(['Via Dorderio']),
#  'Doria': set(['Via Andrea Doria', 'Viale Andrea Doria']),
#  'Dossetti': set(['Via Giuseppe Dossetti']),
#  'Druso': set(['Via Privata Druso']),
#  'Duca': set(['Via Cino Del Duca']),
#  'Duomo': set(['Piazza del Duomo', 'Vicolo Duomo']),
#  u'Dupr\xe8': set([u'Via Giovanni Dupr\xe8']),
#  'Durini': set(['Via Durini', 'Via Giuseppe Durini']),
#  'Duse': set(['Via Eleonora Duse']),
#  'ERG': set(['ERG']),
#  'Easy': set(['Q8 Easy']),
#  'Eching': set(['Via Eching']),
#  'Edera': set(['Via Edera']),
#  'Edison': set(['Via Thomas Alva Edison',
#                 'Viale Edison',
#                 'Viale Thomas Edison',
#                 'Viale Tommaso Edison']),
#  'Einstein': set(['Via Albert Einstein']),
#  'Elvezia': set(['Via Elvezia']),
#  'Emanuele': set(['Via Vittorio Emanuele']),
#  'Emilia': set(['Via Emilia']),
#  'Enel': set(['Enel']),
#  'Eni': set(['Eni']),
#  'Erba': set(['Via Erba']),
#  'Ercolano': set(['Via Ercolano']),
#  'Erg': set(['Total Erg']),
#  'Espinasse': set(['Viale Carlo Espinasse']),
#  'Esso': set(['Esso']),
#  'Esterle': set(['Via Carlo Esterle']),
#  'Etna': set(['Via Monte Etna']),
#  'Eugenio': set(['Via Principe Eugenio']),
#  'Europa': set(['Corso Europa', 'Via Europa', 'Viale Europa']),
#  'Everest': set(['Via Monte Everest']),
#  'Fabbri': set(['Via dei Fabbri']),
#  'Fagnana': set(['Via Fagnana']),
#  'Falck': set(['Via Enrico Falck', 'Via Giorgio Enrico Falck']),
#  'Falcone': set(['Via Falcone', 'Via Giovanni Falcone']),
#  'Fani': set(['Piazza Martiri di Via Fani']),
#  'Fante': set(['Via Cosimo del Fante']),
#  'Fantoli': set(['Via Gaudenzio Fantoli']),
#  'Fara': set(['Via Gustavo Fara']),
#  'Farina': set(['Piazzale Salvatore Farina', 'Via Angelo Farina']),
#  'Farini': set(['Via Carlo Farini']),
#  'Farmacia': set(['Alphega Farmacia']),
#  'Farsaglia': set(['Via Farsaglia']),
#  'Fatebenefratelli': set(['Via Fatebenefratelli']),
#  'Faustino': set(['Via San Faustino']),
#  'Febbraio': set(['Via 11 Febbraio']),
#  'Feraboli': set(['Via Achille Feraboli']),
#  'Fermi': set(['Via Enrico Fermi', 'Viale Enrico Fermi']),
#  'Ferrara': set(['Via Ferrara']),
#  'Ferrari': set(['Piazza Cardinale Andrea Ferrari',
#                  'Via Cardinal Ferrari',
#                  'Via Ferrari',
#                  'Via Giuseppe Ferrari']),
#  'Ferraris': set(['Via Galileo Ferraris']),
#  'Ferravilla': set(['Via Edoardo Ferravilla']),
#  'Ferrucci': set(['Via Francesco Ferrucci']),
#  'Fetonte': set(['Via Fetonte']),
#  'Fidia': set(['Piazza Fidia']),
#  'Fieramosca': set(['Via Ettore Fieramosca']),
#  'Figini': set(['Via Luigi Figini']),
#  'Figino': set(['Via Ambrogio Figino']),
#  'Filanda': set(['via della Filanda']),
#  'Filippetti': set(['Viale Angelo Filippetti']),
#  'Filodrammatici': set(['Via Filodrammatici']),
#  'Filzi': set(['Via Fabio Filzi']),
#  'Fiorani': set(['Via Domenico Fiorani']),
#  'Fioravanti': set(['Via Aristotile Fioravanti']),
#  'Fiordaliso': set(['Via Fiordaliso']),
#  'Fiori': set(['Viale dei Fiori']),
#  'Fiume': set(['Via Fiume']),
#  'Flacco': set(['Via Quinto Orazio Flacco']),
#  'Fleming': set(['Via Alessandro Fleming', 'Via Alexander Fleming']),
#  'Flora': set(['Piazza Flora', 'Via Flora']),
#  'Floriano': set(['Via San Floriano']),
#  'Fogagnolo': set(['Via Umberto Fogagnolo']),
#  'Fogazzaro': set(['Via Antonio Fogazzaro']),
#  'Fondazione': set(['Via Fondazione']),
#  'Fontana': set(['Piazza Fontana', 'Piazza Santa Maria alla Fontana']),
#  'Fontanile': set(['Via Fontanile']),
#  'Foppa': set(['Largo La Foppa', 'Via Vincenzo Foppa']),
#  'Forcella': set(['Via Vincenzo Forcella']),
#  'Forlanini': set(['Via Carlo Forlanini']),
#  'Fornace': set(['Strada Fornace']),
#  'Forni': set(['Via Gerolamo Forni']),
#  'Fortunato': set(['Piazza Giustino Fortunato']),
#  'Foscolo': set(['Via Ugo Foscolo', 'Viale Ugo Foscolo']),
#  'Fossano': set(['Via Bergognone da Fossano']),
#  'Fossati': set(['Via Luigi Fossati']),
#  'Francesca': set(['Via Piero della Francesca']),
#  'Francesco': set(['Via San Francesco']),
#  'Franchetti': set(['Via Raimondo Franchetti']),
#  'Frank': set(['Via Anna Frank']),
#  'Frattini': set(['Via Piero Frattini']),
#  'Freud': set(['Piazza Sigmund Freud']),
#  'Frezzini': set(['Via Padre Frezzini']),
#  'Frignani': set(['Via Angelo Frignani']),
#  'Frisi': set(['Via Francesco Frisi', 'Vicolo Paolo Frisi']),
#  'Friuli': set(['Via Friuli']),
#  'Frua': set(['Via Giuseppe Frua']),
#  'Fucini': set(['Via Renato Fucini']),
#  'Fuggitiva': set(['Via Fuggitiva']),
#  'Fulcorina': set(['Via Santa Maria Fulcorina']),
#  'Fumagalli': set(['Via Angelo Fumagalli', 'Via Graziella Fumagalli']),
#  'Fusina': set(['Piazza Andrea Fusina']),
#  'Fusinato': set(['Via Arnaldo Fusinato']),
#  'Gabba': set(['Via privata Fratelli Gabba']),
#  'Gabetti': set(['Via Giuseppe Gabetti']),
#  'Gabriele': set(['Via Monte San Gabriele']),
#  'Gadda': set(['Via Carlo Emilio Gadda']),
#  'Galbiati': set(['Via Paolo Galbiati']),
#  'Galeno': set(['Via Claudio Galeno']),
#  'Galiani': set(['Via Ferdinando Galiani']),
#  'Galilei': set(['Via Galileo Galilei']),
#  'Galimberti': set(['Via Duccio Galimberti']),
#  'Gallarana': set(['Via Gallarana']),
#  'Gallarate': set(['Via Gallarate']),
#  'Galli': set(['Via Don Gaetano Galli']),
#  'Gallura': set(['Via Gallura']),
#  'Galvani': set(['Via Luigi Galvani']),
#  'Gamberina': set(['Via Gamberina']),
#  'Gandino': set(['Via Cristoforo Gandino']),
#  'Gardenie': set(['Via Gardenie', 'Via delle Gardenie']),
#  'Garibaldi': set(['Corso Giuseppe Garibaldi',
#                    'Piazza Giuseppe Garibaldi',
#                    'Via Anita Garibaldi',
#                    'Via Giuseppe Garibaldi']),
#  'Garigliano': set(['Via Garigliano']),
#  'Gasparotto': set(['Via Leopoldo Gasparotto']),
#  'Gasperi': set(['Via Alcide De Gasperi']),
#  'Generoso': set(['Via Monte Generoso']),
#  'Genesio': set(['Via Monte San Genesio', 'via San Genesio']),
#  'Genova': set(['Corso Genova', 'Via Genova']),
#  'Gentili': set(['Via Alberico Gentili']),
#  'Genziane': set(['Via delle Genziane']),
#  'Gerardo': set(['Via San Gerardo']),
#  'Gerolamo': set(['Piazza San Gerolamo']),
#  'Gerusalemme': set(['Piazza Gerusalemme']),
#  u'Ges\xf9': set([u'Via Ges\xf9']),
#  'Ghilini': set(['Via Giordano Ghilini']),
#  'Ghiringhella': set(['Via Ghiringhella']),
#  'Ghirlanda': set(['Via Ghirlanda']),
#  'Ghisallo': set(['Via Ghisallo', 'Viale del Ghisallo']),
#  'Giacinti': set(['Via dei Giacinti']),
#  'Giacosa': set(['Via Giuseppe Giacosa']),
#  'Giambologna': set(['Via Giambologna']),
#  'Giampietrino': set(['Via Giampietrino']),
#  'Giardina': set(['Via della Giardina']),
#  'Giardini': set(['Via dei Giardini']),
#  'Gigli': set(['Via Beniamino Gigli']),
#  'Giglio': set(['Via del Giglio']),
#  'Ginestra': set(['Via Ginestra']),
#  'Ginestre': set(['Via delle Ginestre']),
#  'Gioberti': set(['Via Vincenzo Gioberti']),
#  'Gioia': set(['Via Flavio Gioia', 'Via Melchiorre Gioia']),
#  'Giolitti': set(['Via Giovanni Giolitti']),
#  'Giordani': set(['Via Pietro Giordani']),
#  'Giorgi': set(['Via Sergio De Giorgi']),
#  'Giorgio': set(['Via per San Giorgio', 'Viale Mulini di San Giorgio']),
#  'Giotto': set(['Via Giotto']),
#  'Giovanna': set(['Viale Regina Giovanna']),
#  'Giovanni': set(['Via San Giovanni']),
#  'Giovi': set(['Via dei Giovi']),
#  'Girola': set(['Via Carlo Girola']),
#  'Giugno': set(['Via 2 Giugno']),
#  'Giulia': set(['Via privata Venezia Giulia']),
#  'Giuliani': set(['Via padre Reginaldo Giuliani', 'piazza Padre Giuliani']),
#  'Giuliano': set(['Via Bartolomeo Giuliano']),
#  'Giulini': set(['Via Giorgio Giulini']),
#  'Giuseppe': set(['Piazza San Giuseppe', 'Via San Giuseppe']),
#  'Giussano': set(['Via Alberto da Giussano']),
#  'Giusti': set(['Via Giuseppe Giusti']),
#  'Gladioli': set(['Via dei Gladioli']),
#  'Glicerio': set(['Via San Glicerio']),
#  'Glicine': set(['Via Glicine']),
#  'Gluck': set(['Via Cristoforo Gluck']),
#  'Gobetti': set(['Via Pietro Gobetti']),
#  'Gogna': set(['Strada per la Cascina Gogna']),
#  'Gogol': set(['Via N .V. Gogol']),
#  'Goito': set(['Via Goito']),
#  'Goldoni': set(['Via Carlo Goldoni']),
#  'Golgi': set(['Via Camillo Golgi']),
#  'Gomes': set(['Via Carlo Gomes']),
#  'Gonfalone': set(['Via privata del Gonfalone']),
#  'Gorizia': set(['Via Gorizia', 'via Gorizia']),
#  'Gorki': set(['Via Massimo Gorki']),
#  'Gottardo': set(['Via San Gottardo']),
#  'Govone': set(['Via Giuseppe Govone']),
#  'Gozzadini': set(['Via Beno De Gozzadini']),
#  'Gozzano': set(['Via Guido Gozzano']),
#  'Grada': set(['Via privata Raffaele De Grada']),
#  'Gramsci': set(['Via Antonio Gramsci', 'Viale Antonio Gramsci']),
#  'Grande': set(['Alzaia Naviglio Grande', 'Piazza Corte Grande']),
#  'Grandi': set(['Via Achille Grandi']),
#  'Grappa': set(['Via Monte Grappa', 'Viale Monte Grappa']),
#  'Grassi': set(['Largo Paolo Grassi', 'Via Giovanni Battista Grassi']),
#  'Gratosoglio': set(['Via Gratosoglio']),
#  'Greco': set(['Piazza Greco']),
#  'Gregorio': set(['Via San Gregorio']),
#  'Greppi': set(['Largo Antonio Greppi', 'Via Mario Greppi']),
#  'Grigna': set(['Via Grigna']),
#  'Grigne': set(['Via Grigne']),
#  'Groane': set(['Via Delle Groane']),
#  'Grossi': set(['Via Tommaso Grossi']),
#  'Grossich': set(['Via Antonio Grossich']),
#  'Guado': set(['Via del Guado']),
#  'Guardini': set(['Via Romano Guardini']),
#  'Guarino': set(['Via Veronese Guarino']),
#  'Guercino': set(['Via Guercino']),
#  'Guerra': set(['Via Puricelli Guerra']),
#  'Guerrazzi': set(['Via Francesco Guerrazzi']),
#  'Guerrina': set(['Via della Guerrina']),
#  'Guerrini': set(['Via Olindo Guerrini']),
#  'Guintellino': set(['Via Guglielmo Guintellino']),
#  'Guzzina': set(['Via Guzzina', 'Via Privata Guzzina']),
#  'Hayez': set(['Via Francesco Hayez']),
#  'Hoepli': set(['Via Ulrico Hoepli']),
#  'Honda': set(['Honda']),
#  'I': set(['Via Umberto I', 'Viale Umberto I']),
#  'II': set(['Corso Vittorio Emanuele II',
#             'Via Giovanni Paolo II',
#             'Via Vittorio Emanuele II']),
#  'III': set(['Via Urbano III']),
#  'IP': set(['IP']),
#  'Icmesa': set(['Via Icmesa']),
#  'Ignoto': set(['Via Milite Ignoto']),
#  'Imola': set(['Via Imola']),
#  'Inama': set(['Via Vigilio Inama']),
#  'Independent': set(['Independent']),
#  'Indipendenza': set(['Piazza Indipendenza',
#                       'Via Indipendenza',
#                       'Viale Indipendenza']),
#  'Industrie': set(['Via delle Industrie', 'Viale delle Industrie']),
#  'Ippocastani': set(['Via Ippocastani']),
#  'Irnerio': set(['Piazza Carlo Irnerio']),
#  'Isimbardi': set(['Via Innocenzo Isimbardi']),
#  'Isonzo': set(['Via Isonzo', 'Viale Isonzo']),
#  'Istria': set(['Piazzale Istria']),
#  'Italia': set(['Corso Italia', 'Piazza Italia', 'Via Italia']),
#  'Jannozzi': set(['Via Carlo Jannozzi']),
#  'Jenner': set(['Viale Edoardo Jenner']),
#  'Jotti': set(['Via Nilde Jotti']),
#  'Jucker': set(['Via Carlo Jucker']),
#  'K2': set(['Via privata Monte K2']),
#  'Kennedy': set(['Via F.lli Kennedy',
#                  'Via John Fitzgerald Kennedy',
#                  'Via John e Robert Kennedy']),
#  'Keplero': set(['Via Giovanni Keplero']),
#  'Keropetrol': set(['Keropetrol']),
#  'King': set(['Via Martin Luther King']),
#  'Koch': set(['Via Robert Koch']),
#  'Koristka': set(['Via Privata Francesco Koristka']),
#  'Labeone': set(['Via privata Labeone']),
#  'Labriola': set(['Via Labriola']),
#  'Lagarina': set(['Via Val Lagarina']),
#  'Lagosta': set(['Piazzale Lagosta']),
#  'Lamarmora': set(['Largo Alfonso Lamarmora']),
#  'Lambertenghi': set(['Via Luigi Porro Lambertenghi']),
#  'Lambrate': set(['Via Lambrate']),
#  'Lambretto': set(['Vicolo Lambretto']),
#  'Lambro': set(['Via Lambro', 'Via San Maurizio al Lambro']),
#  'Lampedusa': set(['Via Lampedusa']),
#  'Lampugnani': set(['Via Giovanni Maria Lampugnani']),
#  'Lana': set(['Via Col di Lana']),
#  'Lancetti': set(['Viale Vincenzo Lancetti']),
#  'Lanino': set(['Via Bernardino Lanino']),
#  'Lanza': set(['Via Giovanni Lanza']),
#  'Lanzone': set(['Via Lanzone']),
#  'Larga': set(['Via Larga']),
#  'Lario': set(['Via Lario']),
#  'Lauro': set(['Via Lauro']),
#  'Lavoro': set(['Via Caduti del Lavoro', 'Via del Lavoro']),
#  'Lazio': set(['Via Lazio']),
#  'Lazzaroni': set(['Via Giuseppina Lazzaroni', 'Via Luigi Lazzaroni']),
#  'Lazzati': set(['Via Giuseppe Lazzati']),
#  'Lecco': set(['Via Lecco']),
#  'Ledro': set(['Via Val di Ledro']),
#  'Lega': set(['Via Lega']),
#  'Legnano': set(['Via Legnano']),
#  'Legnone': set(['Via Monte Legnone']),
#  'Lemene': set(['Via Francesco De Lemene']),
#  'Leoni': set(['Via Ing. Antonio Leoni']),
#  'Leopardi': set(['Via Giacomo Leopardi']),
#  'Lepanto': set(['Via Lepanto']),
#  'Lepetit': set(['Via Roberto Lepetit']),
#  'Lepini': set(['Via Monti Lepini']),
#  'Lepontina': set(['Via Lepontina']),
#  'Lessona': set(['Via Michele Lessona']),
#  'Levati': set(['Via Maria Biffi Levati']),
#  'Liberata': set(['Via Santa Liberata']),
#  'Liberazione': set(['Via Martiri della Liberazione',
#                      'Via della Liberazione',
#                      'Viale della Liberazione']),
#  u'Libert\xe0': set([u'Piazza Libert\xe0',
#                      u'Piazza Volontari della Libert\xe0',
#                      u'Via Caduti della Libert\xe0',
#                      u'Via Libert\xe0',
#                      u'Via Volontari della Libert\xe0',
#                      u'Via della Libert\xe0',
#                      u'Viale Libert\xe0',
#                      u'Viale Martiri della Libert\xe0']),
#  'Libia': set(['Piazzale Libia']),
#  'Lidl': set(['Lidl']),
#  'Ligustro': set(['Via Ligustro']),
#  'Lillapois': set(['Lillapois']),
#  'Lima': set(['Piazza Lima']),
#  'Lino': set(['Via Pesa del Lino']),
#  'Lippi': set(['Via Filippino Lippi']),
#  'Liutprando': set(['Via Privata Liutprando']),
#  'Livio': set(['Via Tito Livio']),
#  'Locatelli': set(['Via Antonio Locatelli']),
#  'Locchi': set(['Via Vittorio Locchi']),
#  'Lodi': set(['Corso Lodi', 'Via Marta Lodi', 'Via Porta Lodi']),
#  'Lodigiana': set(['Via Lodigiana']),
#  'Lombardia': set(['Via Lombardia', 'Viale Lombardia']),
#  'Lomellina': set(['Via Lomellina']),
#  'Longarone': set(['Via Longarone']),
#  'Longoni': set(['Via Emilio Longoni']),
#  'Lorenteggio': set(['Via Molinetto di Lorenteggio']),
#  'Lorenzini': set(['Via Giovanni Lorenzini']),
#  'Lorenzo': set(['Piazza San Lorenzo']),
#  'Loreto': set(['Via Loreto']),
#  'Losanna': set(['Via Losanna']),
#  'Lovera': set(['Via della Lovera']),
#  'Lucania': set(['Via Lucania']),
#  'Lucilio': set(['Via Gaio Lucilio']),
#  'Lucrezio': set(['Via privata Caro Tito Lucrezio']),
#  'Luigi': set(['Via San Luigi']),
#  'Luini': set(['Via Bernardino Luini']),
#  'Luosi': set(['Via Giuseppe Luosi']),
#  'Lusardi': set(['Via Aldo Lusardi']),
#  'Lutero': set(['Via privata Martino Lutero']),
#  'Luzzati': set(['Via Luigi Luzzati']),
#  u'Macall\xe8': set([u'Via Macall\xe8']),
#  'Macchi': set(['Via Mauro Macchi']),
#  u'Macchiavelli': set([u'Via Nicol\xf2 Macchiavelli']),
#  'Maddalena': set(['Spalto Santa Maddalena',
#                    'Via Maddalena',
#                    'Via Santa Maddalena']),
#  'Maderno': set(['Via per Cesano Maderno']),
#  'Madonna': set(['Via Madonna']),
#  'Madonnina': set(['Via Madonnina']),
#  'Maffucci': set(['Via privata Angiolo Maffucci']),
#  'Magellano': set(['Via Ferdinando Magellano']),
#  'Magenta': set(['Corso Magenta', 'Via Magenta']),
#  'Maggio': set(['Via I Maggio', 'Via Primo Maggio', 'Via XXIV Maggio']),
#  'Maggiolini': set(['Via Gerolamo Maggiolini']),
#  'Magni': set(['Via Carlo Magni']),
#  'Magno': set(['Piazza San Magno']),
#  'Majella': set(['Via Privata della Majella']),
#  'Majno': set(['Viale Luigi Majno']),
#  'Majorana': set(['Via Ettore Majorana']),
#  'Malibran': set(['Via Malibran', 'Via Maria Malibran']),
#  'Malpensata': set(['Via Malpensata']),
#  'Mambretti': set(['Via Antonio Mambretti']),
#  'Mameli': set(['Via Goffredo Mameli']),
#  'Mamete': set(['Via San Mamete']),
#  'Manara': set(['Via Luciano Manara']),
#  'Mancini': set(['Via Lodovico Mancini', 'Via Ludovico Mancini']),
#  'Mangiagalli': set(['Via Luigi Mangiagalli']),
#  'Mangili': set(['Via privata Cesare Mangili']),
#  'Manin': set(['Via Daniele Manin']),
#  'Maniscalchi': set(['Via dei Maniscalchi']),
#  'Mantegazza': set(['Via Paolo Mantegazza']),
#  'Mantegna': set(['Via Andrea Mantegna', 'Via Mantegna']),
#  'Mantova': set(['Via Mantova']),
#  'Manzoni': set(['Via Alessandro Manzoni', 'Via Andrea Manzoni']),
#  'Mapelli': set(['Via Achille Mapelli', 'Vicolo Mapelli']),
#  'Maraschi': set(['Via Padre Antonio Maraschi']),
#  'Marcellina': set(['Via Santa Marcellina']),
#  'Marcello': set(['Via Benedetto Marcello']),
#  'Marche': set(['Viale Marche']),
#  'Marchesina': set(['Via Marchesina']),
#  'Marchi': set(['Via Emilio De Marchi']),
#  'Marco': set(['Via San Marco']),
#  'Marconi': set(['Via Guglielmo Marconi', 'Viale Guglielmo Marconi']),
#  'Marcora': set(['Via Giovanni Marcora']),
#  'Marelli': set(['Via Alfonso Marelli',
#                  'Via Rosa Vergani Marelli',
#                  'Viale Ercole Marelli']),
#  'Margherita': set(['Via Santa Margherita']),
#  'Marianna': set(['Via della Marianna']),
#  'Marina': set(['Via Marina']),
#  'Marinetti': set(['Via Filippo Tommaso Marinetti']),
#  'Maritano': set(['Via Felice Maritano']),
#  'Marmolada': set(['Via Marmolada']),
#  'Maronati': set(['Via Carlo Maronati']),
#  'Maroncelli': set(['Via Pietro Maroncelli']),
#  'Marostica': set(['Via Marostica']),
#  'Marsala': set(['Via Marsala']),
#  'Marta': set(['Via Santa Marta']),
#  'Martelli': set(['Via Fiore Martelli']),
#  'Martesana': set(['Viale Martesana']),
#  'Martinelli': set(['Via Martinelli']),
#  'Martini': set(['Via Simone Martini']),
#  'Martino': set(['Via San Martino', 'Vicolo San Martino']),
#  'Martire': set(['Piazza San Pietro Martire']),
#  'Martiri': set(['Piazza dei Piccoli Martiri']),
#  'Marx': set(['Via Carlo Marx']),
#  'Marzabotto': set(['Via Marzabotto']),
#  'Masaniello': set(['Via Masaniello']),
#  'Mascagni': set(['Via Pietro Mascagni']),
#  'Mascheroni': set(['Via Lorenzo Mascheroni']),
#  'Masotto': set(['Via Umberto Masotto']),
#  'Massara': set(['Via Massara']),
#  'Mattei': set(['Mattei', 'Via Enrico Mattei']),
#  'Matteotti': set(['Corso Giacomo Matteotti',
#                    'Piazza Giacomo Matteotti',
#                    'Via Giacomo Matteotti',
#                    'Via Matteotti',
#                    'Viale Giacomo Matteotti']),
#  'Mauri': set(['Via Angelo Mauri']),
#  'Mazda': set(['Mazda']),
#  'Mazzini': set(['Piazza Giuseppe Mazzini', 'Via Giuseppe Mazzini']),
#  'Mazzolari': set(['Piazzetta Don Primo Mazzolari',
#                    'Via Don Primo Mazzolari']),
#  'Mecenate': set(['Via Mecenate']),
#  'Meda': set(['Piazza Meda', 'Via Filippo Meda', 'Via Giuseppe Meda']),
#  'Medici': set(['Via Giacomo Medici', 'Via Marchesa Cornelia Medici']),
#  'Meleri': set(['Via Geremia Meleri']),
#  'Mellerio': set(['Via Giacomo Mellerio']),
#  'Melzi': set(['Via Francesco Melzi']),
#  'Menotti': set(['Via Ciro Menotti']),
#  'Mentana': set(['Via Mentana']),
#  'Merati': set(['Via Angelo Merati']),
#  'Meravigli': set(['Via Meravigli']),
#  'Meraviglia': set(['Via Luigi Meraviglia']),
#  'Mercadante': set(['Via Saverio Mercadante', 'Via Severino Mercadante']),
#  'Mercalli': set(['Via Giuseppe Mercalli']),
#  'Mercedes': set(['Mercedes']),
#  'Merelli': set(['Via Raffaele Merelli']),
#  'Merlino': set(['Via A. da Merlino']),
#  'Messina': set(['Via Messina']),
#  'Metastasio': set(['Via Pietro Metastasio']),
#  'Meucci': set(['Via Antonio Meucci']),
#  'Mezzofanti': set(['Via Cardinale Mezzofanti']),
#  'Micca': set(['Via Pietro Micca']),
#  'Michetti': set(['Via Francesco Paolo Michetti']),
#  'Milanese': set(['Via Milanese']),
#  'Milani': set(['Via Don Milani', 'Via Giovanni Milani']),
#  'Milano': set(['Corso Milano', 'Via Giovanni da Milano', 'Via Milano']),
#  'Mille': set(['Via dei Mille']),
#  'Mimose': set(['Via delle Mimose']),
#  'Mincio': set(['Via Mincio', 'Vicolo Mincio']),
#  'Minoretti': set(['Via Cardinal Dalmazio Minoretti']),
#  'Minturno': set(['Via Minturno']),
#  'Minzoni': set(['Via Don Giovanni Minzoni',
#                  'Via Don Minzoni',
#                  'Via don Giovanni Minzoni']),
#  'Mirabello': set(['Via Villa Mirabello', 'Viale Mirabello']),
#  'Missaglia': set(['Via dei Missaglia']),
#  'Missori': set(['Piazza Giuseppe Missori', 'Via Giuseppe Missori']),
#  'Mistubishi': set(['KIA, Mistubishi']),
#  'Modesta': set(['via Modesta']),
#  'Modigliani': set(['Via Amedeo Modigliani']),
#  'Modignani': set(['Piazza Litta Modignani',
#                    'Via Alessandro Litta Modignani']),
#  'Modrone': set(['Via Uberto Visconti di Modrone']),
#  'Mogadiscio': set(['Via Mogadiscio']),
#  'Molinetto': set(['Largo Molinetto']),
#  'Molini': set(['Vicolo dei Molini']),
#  'Molino': set(['Via Molino']),
#  'Molise': set(['Via Molise', 'Viale Molise']),
#  'Molteni': set(['Via Giuseppe Molteni']),
#  'Mompiani': set(['Via Giacinto Mompiani']),
#  'Moncenisio': set(['Via Moncenisio']),
#  'Moncucco': set(['Via Moncucco']),
#  'Monfalcone': set(['Via Monfalcone']),
#  'Monferrato': set(['Via Monferrato']),
#  'Monforte': set(['Corso Monforte']),
#  u'Monlu\xe8': set([u'Via Monlu\xe8']),
#  'Montale': set(['Via Eugenio Montale']),
#  'Montano': set(['Via Cascina Montano', 'Via Cola Montano']),
#  'Montecassino': set(['Via Montecassino']),
#  'Montefeltro': set(['Via Montefeltro']),
#  'Montegani': set(['Via Lodovico Montegani']),
#  'Montello': set(['Via Montello', 'Viale Montello']),
#  'Montenero': set(['Via Montenero']),
#  'Montessori': set(['Via Maria Montessori']),
#  'Monteverdi': set(['Via Claudio Monteverdi', 'Via Monteverdi']),
#  'Monti': set(['Via Vincenzo Monti']),
#  'Montone': set(['Via Braccio da Montone']),
#  'Montorfano': set(['Via Montorfano']),
#  'Monumento': set(['Piazza Monumento', 'Via al Monumento']),
#  'Monviso': set(['Via Monviso']),
#  'Monza': set(['Via Enrico da Monza',
#                'Via Frate Antonio da Monza',
#                'Via Monza',
#                'Via per Monza',
#                'Viale Monza']),
#  'Morandi': set(['Via Rodolfo Morandi']),
#  'Morelli': set(['Via Domenico Morelli']),
#  'Morgagni': set(['Via Giovanni Battista Morgagni']),
#  'Morghen': set(['Via Raffaello Morghen']),
#  'Moriggia': set(['Via Moriggia']),
#  'Morimondo': set(['Via Morimondo']),
#  'Moro': set(['Via Aldo Moro', 'Via Angelo Moro', 'Via Lodovico il Moro']),
#  'Morona': set(['Via Morona']),
#  'Morosini': set(['Via Emilio Morosini']),
#  'Mortara': set(['Via Mortara']),
#  'Moscova': set(['Via della Moscova']),
#  'Mozart': set(['Via Wolfgang Amadeus Mozart']),
#  'Municipi': set(['Viale dei Municipi']),
#  'Municipio': set(['Piazza Municipio']),
#  'Muratori': set(['Via Lodovico Muratori']),
#  'Murillo': set(['Viale Murillo']),
#  'Muro': set(['Via San Giovanni Sul Muro', 'Vicolo San Giovanni sul Muro']),
#  'Murri': set(['Via Augusto Murri', 'Via Romolo Murri']),
#  'Napoleone': set(['Via Monte Napoleone', 'Via Napoleone']),
#  'Napoli': set(['Piazza Napoli']),
#  'Narcisi': set(['Via Narcisi']),
#  'Nasone': set(['Via Publio Ovidio Nasone',
#                 'Via privata Publio Ovidio Nasone']),
#  'Natta': set(['Via Giulio Natta']),
#  'Negri': set(['Via Ada Negri', 'Via Gaetano Negri']),
#  'Negrotto': set(['Via Michele Pericle Negrotto']),
#  'Nenni': set(['Via Pietro Nenni']),
#  'Nere': set(['Via Giovanni dalle Bande Nere']),
#  'Nerino': set(['Via Nerino']),
#  'Nero': set(['Viale Monte Nero']),
#  'Neruda': set(['Via Pablo Neruda']),
#  'Nevoso': set(['Via Monte Nevoso']),
#  'Niccodemi': set(['Via Dario Niccodemi']),
#  'Niccolini': set(['Via Giovanni Battista Niccolini']),
#  'Nicolao': set(['Via San Nicolao']),
#  'Nicotera': set(['Via Giovanni Nicotera']),
#  'Ninfea': set(['Via Ninfea']),
#  'Nota': set(['Via Alberto Nota']),
#  'Novaro': set(['Via Michele Novaro']),
#  'Novate': set(['Via privata Bertola da Novate']),
#  'Novembre': set(['Via 4 Novembre', 'Via IV Novembre']),
#  'Nullo': set(['Via Francesco Nullo']),
#  'Nuova': set(['Bastioni di Porta Nuova',
#                'Corso di Porta Nuova',
#                'Via Roggia Nuova']),
#  'Nuovo': set(['Via Ponte Nuovo']),
#  u'N\xf6e': set([u'Via Enrico N\xf6e']),
#  'Oberdan': set(['Via Guglielmo Oberdan']),
#  'Occhialini': set(['Piazza Giuseppe "Beppo" Occhialini']),
#  'Occhiate': set(['Via Occhiate']),
#  'Offelera': set(['Via Offelera']),
#  'Oggioni': set(['Piazza Andrea Oggioni']),
#  'Oglio': set(['Via Oglio']),
#  'Oil': set(['General Oil']),
#  'Oldofredi': set(['Via Ercole Oldofredi']),
#  'Oleandri': set(['Via degli Oleandri']),
#  'Olimpya': set(['Via Olimpya']),
#  'Olivari': set(['Via Emilio Olivari']),
#  'Oliveto': set(['Via Monte Oliveto']),
#  'Olmi': set(['Via degli Olmi']),
#  'Olona': set(['Via Olona']),
#  'Omero': set(['Via Omero']),
#  'Omodei': set(['Via Omodei']),
#  'Opel': set(['Opel']),
#  'Oratorio': set(['Via Oratorio']),
#  'Orchidee': set(['Via delle Orchidee']),
#  'Orefici': set(['Via Orefici']),
#  'Oriani': set(['Via Alfredo Oriani', 'Via Barnaba Oriani']),
#  'Origoni': set(['Via Pellegrino Origoni']),
#  'Orione': set(['Via Don Orione']),
#  'Ornato': set(['Via Luigi Ornato']),
#  'Orobia': set(['Via Orobia']),
#  'Orsini': set(['Via Felice Orsini']),
#  'Orti': set(['Via Orti']),
#  'Ortica': set(['Via Ortica']),
#  'Ortigara': set(['Via Monte Ortigara', 'Via Ortigara']),
#  'Osculati': set(['Via Gaetano Osculati']),
#  'Oslavia': set(['Via Oslavia']),
#  'Ospiate': set(['Via Ospiate']),
#  'Ospitaletto': set(['Via Ospitaletto']),
#  'Osti': set(['Via Osti']),
#  'Oxilia': set(['Via Nino Oxilia']),
#  'Ozanam': set(['Via Federico Ozanam']),
#  'Pace': set(['Via Pace', 'Via della Pace']),
#  'Pacini': set(['Via Giovanni Pacini']),
#  'Pacinotti': set(['Via Antonio Pacinotti']),
#  'Pacuvio': set(['Via Marco Pacuvio']),
#  'Padania': set(['Via Padania', 'Viale Padania']),
#  'Padova': set(['Via Padova']),
#  u'Paganini': set([u'Via Niccol\xf2 Paganini']),
#  'Pagano': set(['Via Mario Pagano']),
#  'Paisiello': set(['Via Giovanni Paisiello']),
#  'Palagi': set(['Via Pelagio Palagi']),
#  'Palazzetta': set(['Via della Palazzetta']),
#  'Palazzi': set(['Via Lazzaro Palazzi']),
#  'Palermo': set(['Via Palermo']),
#  'Palestrina': set(['Via Giovanni Pierluigi da Palestrina',
#                     'Via Pier Luigi da Palestrina',
#                     'Via Pierluigi da Palestrina']),
#  'Palestro': set(['Via Palestro']),
#  'Palladio': set(['Via Andrea Palladio']),
#  'Palme': set(['Via delle Palme']),
#  'Palmieri': set(['Via Nicola Palmieri']),
#  'Pampuri': set(["Via Fra' Riccardo Pampuri"]),
#  'Pantano': set(['Via Pantano']),
#  'Pantelleria': set(['Via privata Pantelleria']),
#  'Pantena': set(['Via Val Pantena']),
#  'Panzacchi': set(['Via Enrico Panzacchi']),
#  'Paoli': set(['Via Alessandro Paoli', 'Via Pasquale Paoli']),
#  'Paolo': set(['Piazza San Paolo',
#                'Via San Paolo',
#                'Via Santi Pietro e Paolo',
#                'via S. Paolo']),
#  'Papa': set(['Viale Achille Papa']),
#  'Papiniano': set(['Viale Emilio Papiniano', 'Viale Papiniano']),
#  'Parini': set(['Via Giuseppe Parini', 'Vicolo privato Giuseppe Parini']),
#  'Parma': set(['Via Emilio Parma']),
#  'Parmenide': set(['Via Parmenide']),
#  'Parravicini': set(['Via Gian Francesco Parravicini']),
#  'Parri': set(['Via Ferruccio Parri']),
#  'Partigiani': set(['Via Partigiani', 'Viale Partigiani']),
#  'Pascoli': set(['Via Giovanni Pascoli']),
#  'Pasinetti': set(['Via Antonio Pasinetti']),
#  'Pasini': set(['Via Valentino Pasini']),
#  'Pasolini': set(['Via Pier Paolo Pasolini']),
#  'Passaggio': set(['Via Carlo Passaggio']),
#  'Passarella': set(['Galleria Passarella', 'Via privata Passarella']),
#  'Passerini': set(['Via Antonio Gambacorti Passerini',
#                    'Via Gian Battista Passerini']),
#  'Passione': set(['Via Passione']),
#  'Pastrengo': set(['Via Pastrengo']),
#  'Pasubio': set(['Via Monte Pasubio', 'Via Pasubio', 'Viale Pasubio']),
#  'Pavese': set(['Alzaia Naviglio Pavese', 'Via Pavese']),
#  'Pavoni': set(['Via Lodovico Pavoni']),
#  'Pecchio': set(['Via Giuseppe Pecchio']),
#  'Pedretti': set(['Viale Enrico Pedretti']),
#  'Pellegrini': set(['Via Pellegrino Pellegrini']),
#  'Pellico': set(['Via Silvio Pellico']),
# Via Platone => Via Platone
# Via Carlo Porta => Via Carlo Porta
# Via Pietro da Cernusco => Via Pietro da Cernusco
# Via Lodovico Settala => Via Lodovico Settala
# Piazza Sant'Eustorgio => Piazza Sant'Eustorgio
# university => university
# Via Andrea Ponti => Via Andrea Ponti
# Via Arrigo Boito => Via Arrigo Boito
# Via Giovanni Berchet => Via Giovanni Berchet
# Via Marco d'Oggiono => Via Marco d'Oggiono
# Corso Vercelli => Corso Vercelli
# Supermercati Unes => Supermercati Unes
# Via Santa Maria Fulcorina => Via Santa Maria Fulcorina
# Via Fiori di Pesco => Via Fiori di Pesco
# Via Imola => Via Imola
# Via Napoleone Bonaparte => Via Napoleone Bonaparte
# Via Rovereto => Via Rovereto
# Via Carlo Prina => Via Carlo Prina
# Via Massimo Gorki => Via Massimo Gorki
# Via dei Mille => Via dei Mille
# Via Luigi Figini => Via Luigi Figini
# Via Ambrogio Figino => Via Ambrogio Figino
# Via Selvetto => Via Selvetto
# Lillapois => Lillapois
# Via Sardegna => Via Sardegna
# Via Monte Velino => Via Monte Velino
# Via degli Alpini => Via degli Alpini
# Via delle Stelle Alpine => Via delle Stelle Alpine
# Via Pinalla Aliprandi => Via Pinalla Aliprandi
# Largo La Foppa => Largo La Foppa
# Via Vincenzo Foppa => Via Vincenzo Foppa
# Via Fausto Coppi => Via Fausto Coppi
# Via Niccolò Paganini => Via Niccolò Paganini
# Via Gaetano Salvemini => Via Gaetano Salvemini
# Via Gerardo dei Tintori => Via Gerardo dei Tintori
# Via Piero Bottoni => Via Piero Bottoni
# Via privata Raffaele De Grada => Via privata Raffaele De Grada
# Via Bartolomeo Giuliano => Via Bartolomeo Giuliano
# Via Felice Casati => Via Felice Casati
# Via Gaetano Casati => Via Gaetano Casati
# Via Sandro Pertini => Via Sandro Pertini
# Viale Indipendenza => Viale Indipendenza
# Via Indipendenza => Via Indipendenza
# Piazza Indipendenza => Piazza Indipendenza
# Piazza Enrico Bottini => Piazza Enrico Bottini
# Via Duccio Galimberti => Via Duccio Galimberti
# retail => retail
# Via Filippo Baldinucci => Via Filippo Baldinucci
# Via privata Monte K2 => Via privata Monte K2
# Via Stamira D'Ancona => Via Stamira D'Ancona
# Via Rovigno => Via Rovigno
# Via Gustavo Fara => Via Gustavo Fara
# Via Luigi Tovo => Via Luigi Tovo
# Via Paolo da Cannobio => Via Paolo da Cannobio
# Via Vallazze => Via Vallazze
# Via Primavera => Via Primavera
# Via Palermo => Via Palermo
# Via Tommaso Grossi => Via Tommaso Grossi
# Strada Padana Superiore => Strada Padana Superiore
# Via Santa Giovanna d'Arco => Via Santa Giovanna d'Arco
# Piazza Gae Aulenti => Piazza Gae Aulenti
# Via Gaetana Agnesi => Via Gaetana Agnesi
# Viale Francesco Crispi => Viale Francesco Crispi
# Via Francesco Crispi => Via Francesco Crispi
# Via San Siro => Via San Siro
# Viale Ungheria => Viale Ungheria
# Via Cesare Battisti => Via Cesare Battisti
# Viale Cesare Battisti => Viale Cesare Battisti
# Via Cialdini => Via Cialdini
# Via Pitzigora => Via Pitzigora
# Piazza Lima => Piazza Lima
# Via Cino Del Duca => Via Cino Del Duca
# Via privata Asti => Via privata Asti
# Via Gian Battista Brocchi => Via Gian Battista Brocchi
# Via Moncucco => Via Moncucco
# Via Francesco Arese => Via Francesco Arese
# Viale Piero e Alberto Pirelli => Viale Piero e Alberto Pirelli
# Independent => Independent
# General Oil => General Oil
# Via Loreto => Via Loreto
# Via Antonio Gramsci => Via Antonio Gramsci
# Viale Antonio Gramsci => Viale Antonio Gramsci
# Piazza Santo Stefano => Piazza Santo Stefano
# Via Santo Stefano => Via Santo Stefano
# Via Giuseppe Dossetti => Via Giuseppe Dossetti
# Piazzetta Padre Pio Santo => Piazzetta Padre Pio Santo
# Via Monte Santo => Via Monte Santo
# Viale Monte Santo => Viale Monte Santo
# Via 25 aprile => Via 25 Aprile
# Via Castelfidardo => Via Castelfidardo
# Via Luca della Robbia => Via Luca della Robbia
# Via Sant'Eufemia => Via Sant'Eufemia
# Via Gian Antonio Boltraffio => Via Gian Antonio Boltraffio
# Via Archimede => Via Archimede
# Mercedes => Mercedes
# Via Franco Sacchetti => Via Franco Sacchetti
# Via Torquato Taramelli => Via Torquato Taramelli
# Via del Commercio => Via del Commercio
# Via Pontida => Via Pontida
# Via Federico Zeuner => Via Federico Zeuner
# Via Bruxelles => Via Bruxelles
# construction => construction
# Via Gaspare Rosales => Via Gaspare Rosales
# Via Alessandro Sanquirico => Via Alessandro Sanquirico
# Via Aquileia => Via Aquileia
# Piazzale Aquileia => Piazzale Aquileia
# transformer_tower => transformer_tower
# Via Unità => Via Unità
# Via Michele Lessona => Via Michele Lessona
# greenhouse => greenhouse
# Via Matteo Civitali => Via Matteo Civitali
# Via Osti => Via Osti
# Largo Riccardo Zandonai => Largo Riccardo Zandonai
# Via padre Reginaldo Giuliani => Via padre Reginaldo Giuliani
# piazza Padre Giuliani => piazza Padre Giuliani
# Via Quiete => Via Quiete
# Via Daniele Manin => Via Daniele Manin
# Via Marchesa Cornelia Medici => Via Marchesa Cornelia Medici
# Via Giacomo Medici => Via Giacomo Medici
# Via Benedetto Croce => Via Benedetto Croce
# Via Santa Croce => Via Santa Croce
# Via Croce => Via Croce
# Via Francesco Tamagno => Via Francesco Tamagno
# Via Santa Liberata => Via Santa Liberata
# Viale Addetta => Viale Addetta
# Via Giorgio Enrico Falck => Via Giorgio Enrico Falck
# Via Enrico Falck => Via Enrico Falck
# Via Arnaldo Fusinato => Via Arnaldo Fusinato
# Via Vaniglia => Via Vaniglia
# SP 121 Pobbiano - Agrate => SP 121 Pobbiano - Agrate
# Via Giuseppe Mercalli => Via Giuseppe Mercalli
# Via Corteselle => Via Corteselle
# Via Angelo Mauri => Via Angelo Mauri
# Via Edoardo Bassini => Via Edoardo Bassini
# Via Valentino Pasini => Via Valentino Pasini
# Via Val Lagarina => Via Val Lagarina
# Via Adamello => Via Adamello
# Via Po => Via Po
# Largo Po => Largo Po
# Via Cesare Cantù => Via Cesare Cantù
# Via Alcide De Gasperi => Via Alcide De Gasperi
# Via Filippo Caronti => Via Filippo Caronti
# Via San Cristoforo => Via San Cristoforo
# Via Diodoro Siculo => Via Diodoro Siculo
# Via Broni => Via Broni
# Via Brugallo => Via Brugallo
# Via Guglielmo Guintellino => Via Guglielmo Guintellino
# Piazza Oreste Biraghi => Piazza Oreste Biraghi
# Via Luigi Biraghi => Via Luigi Biraghi
# Via Giuseppe Gabetti => Via Giuseppe Gabetti
# Via Mantegna => Via Mantegna
# Via Andrea Mantegna => Via Andrea Mantegna
# Via Gorizia => Via Gorizia
# via Gorizia => via Gorizia
# Via Vincenzo Viviani => Via Vincenzo Viviani
# Via Lodovico Mancini => Via Lodovico Mancini
# Via Ludovico Mancini => Via Ludovico Mancini
# Via Marco Antonio Colonna => Via Marco Antonio Colonna
# Piazza Gianni Citterio => Piazza Gianni Citterio
# Via Filippo Argelati => Via Filippo Argelati
# Via Cassino d'Alberi => Via Cassino d'Alberi
# Via Leopoldo Gasparotto => Via Leopoldo Gasparotto
# Via Varsavia => Via Varsavia
# Via Bartolomeo Zucchi => Via Bartolomeo Zucchi
# Via Giuseppe Zucchi => Via Giuseppe Zucchi
# Via Marco Tullio Cicerone => Via Marco Tullio Cicerone
# via Modesta => via Modesta
# Via Carlo Emilio Gadda => Via Carlo Emilio Gadda
# Via Solferino => Via Solferino
# Via Crescenzago => Via Crescenzago
# Via Edmondo De Amicis => Via Edmondo De Amicis
# Via Fratelli Rosselli => Via Fratelli Rosselli
# Via Camillo Ugoni => Via Camillo Ugoni
# Via Cecilio Stazio => Via Cecilio Stazio
# Via Alessio di Tocqueville => Via Alessio di Tocqueville
# kindergarten => kindergarten
# Piazza Luigi di Savoia => Piazza Luigi di Savoia
# Via Campestre => Via Campestre
# window => window
# Via Pozzo Antico => Via Pozzo Antico
# Via Comune Antico => Via Comune Antico
# Via dell'Orso => Via dell'Orso
# Piazza Cincinnato => Piazza Cincinnato
# Via Galileo Ferraris => Via Galileo Ferraris
# Piazza Flora => Piazza Flora
# Via Flora => Via Flora
# Via Desiderio => Via Desiderio
# Via Adria => Via Adria
# Via Benvenuto Cellini => Via Benvenuto Cellini
# Via San Raffaele => Via San Raffaele
# Via San Francesco d'Assisi => Via San Francesco d'Assisi
# Piazza San Francesco d'Assisi => Piazza San Francesco d'Assisi
# abandoned => abandoned
# Via Gabriele D'Annunzio => Via Gabriele D'Annunzio
# Via Giacomo Balconi => Via Giacomo Balconi
# Via Rugabella => Via Rugabella
# Via Luigi Luzzati => Via Luigi Luzzati
# Via alla Porada => Via alla Porada
# Via Rozzano => Via Rozzano
# Via Giulio Carcano => Via Giulio Carcano
# Via Filippo Carcano => Via Filippo Carcano
# Via dei Missaglia => Via dei Missaglia
# Via Rimini => Via Rimini
# Via Antonio Bordoni => Via Antonio Bordoni
# generic => generic
# Via privata del Gonfalone => Via privata del Gonfalone
# Via Lazzaro Spallanzani => Via Lazzaro Spallanzani
# Via Luigi Sacco => Via Luigi Sacco
# grandstand => grandstand
# Via Antonio Cechov => Via Antonio Cechov
# Via Don Galileo Vercesi => Via Don Galileo Vercesi
# Via Galileo Vercesi => Via Galileo Vercesi
# Via Senato => Via Senato
# Via Gerolamo Savonarola => Via Gerolamo Savonarola
# Via Offelera => Via Offelera
# Via Luigi Colombo => Via Luigi Colombo
# Viale Cristoforo Colombo => Viale Cristoforo Colombo
# Via Giuseppe Colombo => Via Giuseppe Colombo
# Via Cristoforo Colombo => Via Cristoforo Colombo
# Via Busto Arsizio => Via Busto Arsizio
# Viale Martesana => Viale Martesana
# Via Giuseppe Broggi => Via Giuseppe Broggi
# Total => Total
# Foro Buonaparte => Foro Buonaparte
# Via Melchiorre Gioia => Via Melchiorre Gioia
# Via Flavio Gioia => Via Flavio Gioia
# Via Ilarione Rancati => Via Ilarione Rancati
# TIM => Tim
# Via Augusto Murri => Via Augusto Murri
# Via Romolo Murri => Via Romolo Murri
# Via Sebenico => Via Sebenico
# Via Privata Danilo => Via Privata Danilo
# residential => residential
# Via Carlo Bo => Via Carlo Bo
# Via Ludovico di Breme => Via Ludovico di Breme
# Via Don Minzoni => Via Don Minzoni
# Via don Giovanni Minzoni => Via don Giovanni Minzoni
# Via Don Giovanni Minzoni => Via Don Giovanni Minzoni
# Esso => Esso
# Via Giuseppe Verdi => Via Giuseppe Verdi
# Via Carlo Tenca => Via Carlo Tenca
# Via San Clemente => Via San Clemente
# Via Cardinal Dalmazio Minoretti => Via Cardinal Dalmazio Minoretti
# Via Azzo Carbonera => Via Azzo Carbonera
# Via Antonio Mambretti => Via Antonio Mambretti
# Via Salazar => Via Salazar
# Puff => Puff
# Via Torazza => Via Torazza
# Via Aldina => Via Aldina
# Via Gerolamo Maggiolini => Via Gerolamo Maggiolini
# Viale Benessere => Viale Benessere
# Via Azalee => Via Azalee
# Via Tortona => Via Tortona
# Via Gaspare Rotondi => Via Gaspare Rotondi
# shed => shed
# Corso di Porta Ticinese => Corso di Porta Ticinese
# Ripa di Porta Ticinese => Ripa di Porta Ticinese
# Piazza della Scala => Piazza della Scala
# Piazza Salvo D'Acquisto => Piazza Salvo D'Acquisto
# Via Salvo D'Acquisto => Via Salvo D'Acquisto
# Via Luigi Pirandello => Via Luigi Pirandello
# Via Caduti del Lavoro => Via Caduti del Lavoro
# Via del Lavoro => Via del Lavoro
# Via Federico Ozanam => Via Federico Ozanam
# Via Morona => Via Morona
# Via Carlo Girola => Via Carlo Girola
# Via Valenza => Via Valenza
# Via Cola Montano => Via Cola Montano
# Via Cascina Montano => Via Cascina Montano
# Via Achille Varisco => Via Achille Varisco
# Via Don Biagio Volonteri => Via Don Biagio Volonteri
# Via Carlo Jannozzi => Via Carlo Jannozzi
# Via Pastrengo => Via Pastrengo
# Via Francesco Petrarca => Via Francesco Petrarca
# Viale Francesco Petrarca => Viale Francesco Petrarca
# Via Aristotele => Via Aristotele
# Via Puglia => Via Puglia
# Viale Rodi => Viale Rodi
# Viale Enrico Pedretti => Viale Enrico Pedretti
# Via Bernardo Rucellai => Via Bernardo Rucellai
# Via Zuavi => Via Zuavi
# Via Romano Guardini => Via Romano Guardini
# Via Giuseppe Garibaldi => Via Giuseppe Garibaldi
# Piazza Giuseppe Garibaldi => Piazza Giuseppe Garibaldi
# Corso Giuseppe Garibaldi => Corso Giuseppe Garibaldi
# Via Anita Garibaldi => Via Anita Garibaldi
# Via Carlo Valvassori Peroni => Via Carlo Valvassori Peroni
# Via Beato Angelico => Via Beato Angelico
# Piazzale Luigi Cadorna => Piazzale Luigi Cadorna
# Via Cadorna => Via Cadorna
# Via Luigi Cadorna => Via Luigi Cadorna
# Via Guercino => Via Guercino
# Via Marco Pacuvio => Via Marco Pacuvio
# Viale Isonzo => Viale Isonzo
# Via Isonzo => Via Isonzo
# Via Camillo Prampolini => Via Camillo Prampolini
# utility => utility
# Via Enrico Cernuschi => Via Enrico Cernuschi
# Via Eleonora Duse => Via Eleonora Duse
# Via Pietro Maroncelli => Via Pietro Maroncelli
# Via Monte Etna => Via Monte Etna
# Via Santuario delle Grazie Vecchie => Via Santuario delle Grazie Vecchie
# Via Gratosoglio => Via Gratosoglio
# Via Silvio Spaventa => Via Silvio Spaventa
# Via San Faustino => Via San Faustino
# Via Alessandro Tadino => Via Alessandro Tadino
# Via Alpi => Via Alpi
# Via Zebedia => Via Zebedia
# Via Monti Lepini => Via Monti Lepini
# Vicolo Alba => Vicolo Alba
# Via don Carlo Colnaghi => Via don Carlo Colnaghi
# Via Gamberina => Via Gamberina
# Via delle Peonie => Via delle Peonie
# Viale Argonne => Viale Argonne
# Piazza Giustino Fortunato => Piazza Giustino Fortunato
# Via Fontanile => Via Fontanile
# Via Angelo Frignani => Via Angelo Frignani
# Via Luigi Calori => Via Luigi Calori
# Via Appennini => Via Appennini
# Via Carlo Darwin => Via Carlo Darwin
# Via Darwin => Via Darwin
# Via Ferrante Aporti => Via Ferrante Aporti
# Via privata Passarella => Via privata Passarella
# Galleria Passarella => Galleria Passarella
# Via Bruno Buozzi => Via Bruno Buozzi
# Via Regina Teodolinda => Via Regina Teodolinda
# Via Nino Oxilia => Via Nino Oxilia
# Viale Gian Battista Stucchi => Viale Gian Battista Stucchi
# Via privata Bertola da Novate => Via privata Bertola da Novate
# Via Giuseppe Taccioli => Via Giuseppe Taccioli
# Via Giorgio Giulini => Via Giorgio Giulini
# Via Luigi Porro Lambertenghi => Via Luigi Porro Lambertenghi
# Via Monsignor Luigi Talamoni => Via Monsignor Luigi Talamoni
# Via Tito Speri => Via Tito Speri
# Via Garigliano => Via Garigliano
# Viale Corsica => Viale Corsica

# %%
###Preparing for Database - SQL(data.py) using the sample file


"""
After auditing is complete the next step is to prepare the data to be inserted into a SQL database.
To do so you will parse the elements in the OSM XML file, transforming them from document format to
tabular format, thus making it possible to write to .csv files.  These csv files can then easily be
imported to a SQL database as tables.

The process for this transformation is as follows:
- Use iterparse to iteratively step through each top level element in the XML
- Shape each element into several data structures using a custom function
- Utilize a schema and validation library to ensure the transformed data is in the correct format
- Write each data structure to the appropriate .csv files

## Shape Element Function
The function should take as input an iterparse Element object and return a dictionary.

### If the element top level tag is "node":
The dictionary returned should have the format {"node": .., "node_tags": ...}

The "node" field should hold a dictionary of the following top level node attributes:
- id
- user
- uid
- version
- lat
- lon
- timestamp
- changeset
All other attributes can be ignored

The "node_tags" field should hold a list of dictionaries, one per secondary tag. Secondary tags are
child tags of node which have the tag name/type: "tag". Each dictionary should have the following
fields from the secondary tag attributes:
- id: the top level node id attribute value
- key: the full tag "k" attribute value if no colon is present or the characters after the colon if one is.
- value: the tag "v" attribute value
- type: either the characters before the colon in the tag "k" value or "regular" if a colon
        is not present.

Additionally,

- if the tag "k" value contains problematic characters, the tag should be ignored
- if the tag "k" value contains a ":" the characters before the ":" should be set as the tag type
  and characters after the ":" should be set as the tag key
- if there are additional ":" in the "k" value they and they should be ignored and kept as part of
  the tag key. For example:

  <tag k="addr:street:name" v="Lincoln"/>
  should be turned into
  {'id': 12345, 'key': 'street:name', 'value': 'Lincoln', 'type': 'addr'}

- If a node has no secondary tags then the "node_tags" field should just contain an empty list.

The final return value for a "node" element should look something like:

{'node': {'id': 757860928,
          'user': 'uboot',
          'uid': 26299,
       'version': '2',
          'lat': 41.9747374,
          'lon': -87.6920102,
          'timestamp': '2010-07-22T16:16:51Z',
      'changeset': 5288876},
 'node_tags': [{'id': 757860928,
                'key': 'amenity',
                'value': 'fast_food',
                'type': 'regular'},
               {'id': 757860928,
                'key': 'cuisine',
                'value': 'sausage',
                'type': 'regular'},
               {'id': 757860928,
                'key': 'name',
                'value': "Shelly's Tasty Freeze",
                'type': 'regular'}]}

### If the element top level tag is "way":
The dictionary should have the format {"way": ..., "way_tags": ..., "way_nodes": ...}

The "way" field should hold a dictionary of the following top level way attributes:
- id
-  user
- uid
- version
- timestamp
- changeset

All other attributes can be ignored

The "way_tags" field should again hold a list of dictionaries, following the exact same rules as
for "node_tags".

Additionally, the dictionary should have a field "way_nodes". "way_nodes" should hold a list of
dictionaries, one for each nd child tag.  Each dictionary should have the fields:
- id: the top level element (way) id
- node_id: the ref attribute value of the nd tag
- position: the index starting at 0 of the nd tag i.e. what order the nd tag appears within
            the way element

The final return value for a "way" element should look something like:

{'way': {'id': 209809850,
         'user': 'chicago-buildings',
         'uid': 674454,
         'version': '1',
         'timestamp': '2013-03-13T15:58:04Z',
         'changeset': 15353317},
 'way_nodes': [{'id': 209809850, 'node_id': 2199822281, 'position': 0},
               {'id': 209809850, 'node_id': 2199822390, 'position': 1},
               {'id': 209809850, 'node_id': 2199822392, 'position': 2},
               {'id': 209809850, 'node_id': 2199822369, 'position': 3},
               {'id': 209809850, 'node_id': 2199822370, 'position': 4},
               {'id': 209809850, 'node_id': 2199822284, 'position': 5},
               {'id': 209809850, 'node_id': 2199822281, 'position': 6}],
 'way_tags': [{'id': 209809850,
               'key': 'housenumber',
               'type': 'addr',
               'value': '1412'},
              {'id': 209809850,
               'key': 'street',
               'type': 'addr',
               'value': 'West Lexington St.'},
              {'id': 209809850,
               'key': 'street:name',
               'type': 'addr',
               'value': 'Lexington'},
              {'id': '209809850',
               'key': 'street:prefix',
               'type': 'addr',
               'value': 'West'},
              {'id': 209809850,
               'key': 'street:type',
               'type': 'addr',
               'value': 'Street'},
              {'id': 209809850,
               'key': 'building',
               'type': 'regular',
               'value': 'yes'},
              {'id': 209809850,
               'key': 'levels',
               'type': 'building',
               'value': '1'},
              {'id': 209809850,
               'key': 'building_id',
               'type': 'chicago',
               'value': '366409'}]}


import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

OSM_PATH = "Milano.osm"

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

SCHEMA = schema.schema

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def correct_k(k):
    index=k.find(':')
    typ=k[:index]
    k=k[index+1:]    
    return k,typ

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    # YOUR CODE HERE
    if element.tag=='node':
        for i in node_attr_fields:
            node_attribs[i]=element.attrib[i]
            
    if element.tag=='way':
        for i in way_attr_fields:
            way_attribs[i]=element.attrib[i]
        
    for tag in element.iter("tag"):
        dic={}
        attributes=tag.attrib
        if problem_chars.search(tag.attrib['k']):
            continue
        
        if element.tag=='node':
            dic['id']=node_attribs['id']
        else:
            dic['id']=way_attribs['id']
        
        dic['value'] = attributes['v']

        colon_k=LOWER_COLON.search(tag.attrib['k'])
        if colon_k:
            print colon_k.group(0)
            print tag.attrib['k']
            dic['key'],dic['type']=correct_k(tag.attrib['k'])
        else:
            dic['key']=attributes['k']
            dic['type']='regular'
        
        
        #print dic
        tags.append(dic)
    
    if element.tag=='way':
        position=0
        for nd in element.iter("nd"):
            way_node_dic={}
            way_node_dic['id']=way_attribs['id']
            way_node_dic['node_id']=nd.attrib['ref']
            way_node_dic['position']=position
            position = position + 1
            way_nodes.append(way_node_dic)
    
    if element.tag == 'node':
        return {'node': node_attribs, 'node_tags': tags}
    elif element.tag == 'way':
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}
     


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    Yield element if it is the right type of tag

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    Raise ValidationError if element does not match schema
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    Extend csv.DictWriter to handle Unicode input

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    Iteratively process each XML element and write to csv(s)

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    # Note: Validation is ~ 10X slower. For the project consider using a small
    # sample of the map when validating.
    process_map(OSM_PATH, validate=True)
"""

# %%
path = 'C:\Users\SAMSUNG\Documents\Udacity\Nano_degree_Data_analyst\P3 - Wrangle OpenStreetMap Data'
print 'The size in bytes of nodes = {} bytes'.format(os.path.getsize('nodes.csv'))
print 'The size in bytes of nodes tags = {} bytes'.format(os.path.getsize('nodes_tags.csv'))
print 'The size in bytes of ways = {} bytes'.format(os.path.getsize('ways.csv'))
print 'The size in bytes of ways node is = {} bytes'.format(os.path.getsize('ways_nodes.csv'))
print 'The size in bytes of ways tags is = {} bytes'.format(os.path.getsize('ways_tags.csv'))
# Out:
# The size in bytes of nodes = 26908052 bytes
# The size in bytes of nodes tags = 2170623 bytes
# The size in bytes of ways = 2984762 bytes
# The size in bytes of ways node is = 10049963 bytes
# The size in bytes of ways tags is = 4205980 bytes

# %%
##### Importing the data on sql
###  sqlite3 MilanMap.db
###     .mode csv
###    .import nodes.csv nodes
###    .import ways.csv ways
###    .import nodes_tags.csv nodes_tags
###    delete from nodes_tags where id = 'id';
###    .import ways_tags.csv ways_tags
###    delete from ways_tags where id = 'id';
###    .import ways_nodes.csv ways_nodes
###    delete from ways_nodes where id = 'id';

# %%
### Quering the database with SQL   
"""
Number of nodes    
SELECT COUNT(*) FROM nodes;    
330438     

Number of ways    
SELECT COUNT(*) FROM ways;    
49979    

Top 5 contributing users    
SELECT t.user, COUNT(*) as Total_users    
FROM (SELECT user FROM nodes UNION ALL SELECT user FROM ways) t    
GROUP BY t.user       
ORDER BY Total_users DESC    
LIMIT 5;      

Alecs01,52948     
ilrobi,31997
adirricor,25865
Guido_RL,23109
fedc,15701      

Top 5 most common name of street in Milan     
SELECT tags.value as Street_Name, COUNT(*) as Total_count   
FROM (SELECT * FROM nodes_tags UNION ALL    
      SELECT * FROM ways_tags) tags     
WHERE tags.key = 'street'    
GROUP BY Street_Name    
ORDER BY Total_count DESC    
LIMIT 5;    

"Via Giuseppe Garibaldi",40      
"Via Alessandro Manzoni",35     
"Via Alessandro Volta",33     
"Via Roma",33    
"Via Piave",32     

Top 5 type of buildings in Milan     
SELECT tags.value as Building_Type, COUNT(*) as Total_building     
FROM (SELECT * FROM nodes_tags UNION ALL        
      SELECT * FROM ways_tags) tags      
WHERE key ='building' and value != 'yes'     
GROUP BY Building_Type    
ORDER BY Total_building DESC    
LIMIT 5;    
house,2050     
apartments,1974     
residential,1372     
industrial,937     
garage,206     

Top 5 shop type in Milan     
SELECT tags.value as Shop_Type, COUNT(*) as Total_shop      
FROM (SELECT * FROM nodes_tags UNION ALL     
      SELECT * FROM ways_tags) tags   
WHERE key ='shop'
GROUP BY Shop_Type
ORDER BY Total_shop DESC
LIMIT 5;
clothes,106
supermarket,68
hairdresser,58
bakery,37
car_repair,33

Top 5 of cuisine in Milan
SELECT nodes_tags.value as Restaurant_Type, COUNT(*) as Total_count
FROM nodes_tags 
    JOIN (SELECT DISTINCT(id) FROM nodes_tags WHERE value='restaurant') i
    ON nodes_tags.id=i.id
WHERE nodes_tags.key='cuisine'
GROUP BY Restaurant_Type
ORDER BY Total_count DESC
LIMIT 5;
pizza,33
italian,26
regional,8
sushi,5
chinese,4

For curiosity I also wanted to find the top 5 brand name we can have in Milan.
SELECT tags.value as Brand_Name, COUNT(*) as Total_count 
FROM (SELECT * FROM nodes_tags UNION ALL 
      SELECT * FROM ways_tags) tags
WHERE tags.key = 'brand'
GROUP BY Brand_Name
ORDER BY Total_count DESC
LIMIT 5;
Shell,11
Tamoil,10
Agip,8
Eni,7
Esso,7
"""

# %% [markdown]
# Using this database we can see that the most common name for street is Giuseppe Garibaldi who was a central figure in the Italian Risorgimento.
# The most type of buidings is house which is unexpected as I always though that there more apartments than buildings in Milan.
# As I expected the most type of shop are for clothes, in fact Milan is know as the "shopping city" and the most common restaurant is pizza as Italy is the country of pizza.
# The most common brand is the petrol brand Shell for fuel.

# %% [markdown]
# ### Other ideas about the datasets
#
# A good idea could be to find in which streets are these clothes shops? Which address code had the most common name of Garibaldi?
# Milan is a big city so found these others queries could help to know it better.
# I didn't extract the whole name of streets because I was only interest in the lastname, but I saw that there are some inaccuracies. So this could be an idea to improve the data.
# There is a little gap between the house type and apartments, maybe we can go deeper on this also.
